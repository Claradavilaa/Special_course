# %%
from pathlib import Path
import numpy as np
import pandas as pd
from collections import defaultdict


from eelbrain import NDVar, UTS, Sensor, Case, Var, Factor, Dataset, save, plot, boosting

from ridge_regression_functions import (
    load_all_trials,
    split_trials_by_condition,
    WIN_OFFSET1,
    WIN_OFFSET2,
)

# 10 ms sampling → 100 Hz
SAMPLE_RATE = 100.0
TSTEP = 1.0 / SAMPLE_RATE  # 0.01 s

FRONTAL_MIDLINE = ['AFz','AF3','AF4','Fz','F1','F2','F3','F4','FC3','FC1','FC2','FC4','Cz','C3','C1','C2','C4']

# %%
from eelbrain import load

path_dec = r"C:\Users\cdd\Documents\Uni\Special_course\code\Special_course\THESIS\eelbrain\TRF\dec_eeg_to_ppd_sub-042_l13.pickle"
path_enc = r"C:\Users\cdd\Documents\Uni\Special_course\code\Special_course\THESIS\eelbrain\TRF\enc_ppd_to_eeg_sub-042_l13.pickle"

dec_42_l13 = load.unpickle(path_dec)
enc_42_l13 = load.unpickle(path_enc)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 6
#       3 path_dec = r"C:\Users\cdd\Documents\Uni\Special_course\code\Special_course\THESIS\eelbrain\TRF\dec_eeg_to_ppd_sub-042_l13.pickle"
#       4 path_enc = r"C:\Users\cdd\Documents\Uni\Special_course\code\Special_course\THESIS\eelbrain\TRF\enc_ppd_to_eeg_sub-042_l13.pickle"
# ----> 6 dec_42_l13 = load.unpickle(path_dec)
#       7 enc_42_l13 = load.unpickle(path_enc)
#
# File c:\Users\cdd\AppData\Local\anaconda3\envs\eelbrain-env\Lib\site-packages\eelbrain\_io\pickle.py:142, in unpickle(path)
#     139                 path = new_path
#     140                 break
# --> 142 with open(path, 'rb') as fid:
#     143     unpickler = EelUnpickler(fid, encoding='latin1')
#     144     try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\cdd\\Documents\\Uni\\Special_course\\code\\Special_course\\THESIS\\eelbrain\\TRF\\dec_eeg_to_ppd_sub-042_l13.pickle'

# %%
# decoding performance (scalar r, because y was ppd)
print(dec_42_l13.r)

# decoder kernel (time × sensor or sensor × time, depending on version)
h_dec = dec_42_l13.h_scaled
print(h_dec)
# e.g. TRF for Fz
h_Fz_dec = h_dec.sub(sensor='Fz')
plot.UTS(h_Fz_dec, axtitle="ppd → Fz TRF")

# predicted pupil (case × time)
ppd_pred = dec_42_l13.y_pred
print(ppd_pred)
# Out:
# 0.11214931442192845
# <NDVar 'eeg': 17 sensor, 324 time>
# None

# %%
h_enc = enc_42_l13.h  # NDVar
print(h_enc)   # to see its dimensions
h_Fz_enc = h_enc.sub(sensor='Fz')    # NDVar(time)
plot.UTS(h_Fz_enc, axtitle="ppd → Fz TRF")
# Out:
# <NDVar 'ppd': 17 sensor, 324 time>

# %%
r = enc_42_l13.r
print(r)

for ch in FRONTAL_MIDLINE:
    print(ch, float(r.sub(sensor=ch)))
# Out:
# <NDVar 'Correlation': 17 sensor>
# AFz -0.035634634533719255
# AF3 0.02891711229203695
# AF4 0.032178547117065
# Fz 0.05148911183137397
# F1 0.039213329607817315
# F2 0.0004745218927270042
# F3 0.06469577752559395
# F4 -0.05446501177550359
# FC3 0.009715291373713901
# FC1 0.034932509053482316
# FC2 0.022429438613552805
# FC4 -0.06081435837962243
# Cz -0.06475011272086294
# C3 -0.04656621071259087
# C1 -0.03291001598116996
# C2 -0.006941325742481207
# C4 0.03438144418092102

# %%
lags_peak = {}
for ch in FRONTAL_MIDLINE:
    h_ch = h_enc.sub(sensor=ch).sub(time=(0.0, 1.5))
    t = h_ch.time.times
    y = h_ch.x
    i_peak = np.argmax(np.abs(y))
    lags_peak[ch] = t[i_peak] * 1000  # ms

print(lags_peak)
# Out:
# {'AFz': np.float64(20.0), 'AF3': np.float64(1490.0), 'AF4': np.float64(1490.0), 'Fz': np.float64(1490.0), 'F1': np.float64(10.0), 'F2': np.float64(10.0), 'F3': np.float64(1480.0), 'F4': np.float64(10.0), 'FC3': np.float64(0.0), 'FC1': np.float64(0.0), 'FC2': np.float64(780.0), 'FC4': np.float64(1490.0), 'Cz': np.float64(1490.0), 'C3': np.float64(970.0), 'C1': np.float64(1490.0), 'C2': np.float64(1490.0), 'C4': np.float64(1490.0)}

# %%
eeg_pred = enc_42_l13.y_pred        # NDVar(case × sensor × time)
print(eeg_pred)
# Out:
# None

# %%
from eelbrain import plot
plot.Topomap(r, axtitle="ppd → EEG predictive power (r)")

# %%
import re
from pathlib import Path

import numpy as np
import pandas as pd
from scipy.stats import ttest_1samp
from eelbrain import load


def analyze_all_decoders(
    trf_dir=r"C:\Users\cdd\Documents\Uni\Special_course\code\Special_course\THESIS\eelbrain\ran1\TRF"
):
    """
    Read all dec_eeg_to_ppd_sub-xxx_lyy.pickle decoders in `trf_dir`,
    extract correlation r and predictive power, and test whether r > 0.

    Returns
    -------
    df : pandas.DataFrame
        Columns: ['subject', 'load', 'r', 'var_explained']
    """
    trf_dir = Path(trf_dir)
    pattern = "dec_eeg_to_ppd_sub-*_l*.pickle"

    rows = []

    for fpath in trf_dir.glob(pattern):
        name = fpath.name
        # parse subject and load from filename: dec_eeg_to_ppd_sub-042_l13.pickle
        m = re.match(r"dec_eeg_to_ppd_sub-(\d+)_l(\d+)\.pickle", name)
        if not m:
            print(f"[skip] Could not parse subject/load from {name}")
            continue

        subj = int(m.group(1))
        load_val = int(m.group(2))

        # load BoostingResult
        dec = load.unpickle(fpath)

        # r: scalar (because y = ppd is 1D). Handle NDVar or float.
        try:
            r_val = float(dec.r)
        except Exception:
            r_val = float(np.asarray(dec.r.x).item())

        # predictive power: proportion_explained (0–1) → %
        var_exp = getattr(dec, "proportion_explained", None)
        if var_exp is not None:
            try:
                ve = float(var_exp) * 100.0
            except Exception:
                ve = float(np.asarray(var_exp.x).item()) * 100.0
        else:
            ve = np.nan

        rows.append({
            "subject": subj,
            "load": load_val,
            "r": r_val,
            "var_explained": ve,
            "file": name,
        })

    if not rows:
        print("No decoder files found; check TRF directory and naming.")
        return pd.DataFrame()

    df = pd.DataFrame(rows)
    print("\nCollected decoder results:")
    print(df.sort_values(["subject", "load"]))

    # === Overall test: is mean r > 0 ? ===
    r_all = df["r"].values
    mean_r = r_all.mean()
    sd_r = r_all.std(ddof=1)
    n = len(r_all)

    # two-sided t-test vs 0, then convert to one-sided if mean_r > 0
    t_stat, p_two = ttest_1samp(r_all, popmean=0.0)
    if mean_r >= 0:
        p_one = p_two / 2.0
    else:
        p_one = 1.0 - p_two / 2.0  # if mean < 0, one-sided r > 0 is not interesting anyway

    var_explained_all = df["var_explained"].values
    mean_ve = var_explained_all.mean()
    sd_ve = var_explained_all.std(ddof=1)
    n_ve = len(var_explained_all)

    t_stat_ve, p_two_ve = ttest_1samp(var_explained_all, popmean=0.0)
    if mean_ve >= 0:
        p_one_ve = p_two_ve / 2.0
    else:
        p_one_ve = 1.0 - p_two_ve / 2.0

    print("\n=== Overall decoder r (EEG → ppd) ===")
    print(f"n = {n}")
    print(f"mean r = {mean_r:.4f}, SD = {sd_r:.4f}")
    print(f"t({n-1}) = {t_stat:.3f}, one-sided p (r>0) = {p_one:.3e}")

    # Also show overall predictive power
    if df["var_explained"].notna().any():
        mean_ve = df["var_explained"].mean()
        sd_ve = df["var_explained"].std(ddof=1)
        print(f"mean % variance explained = {mean_ve:.3f} ± {sd_ve:.3f}")
        print(f"t({n_ve-1}) = {t_stat_ve:.3f}, one-sided p (var explained > 0) = {p_one_ve:.3e}")

    # === Per-load tests ===
    print("\n=== Per-load tests (decoder r > 0) ===")
    for load_val in sorted(df["load"].unique()):
        sub_df = df[df["load"] == load_val]
        r_vals = sub_df["r"].values
        if len(r_vals) < 2:
            print(f"Load {load_val}: only {len(r_vals)} subject(s); skipping t-test.")
            continue
        mean_r_l = r_vals.mean()
        sd_r_l = r_vals.std(ddof=1)
        t_l, p2_l = ttest_1samp(r_vals, popmean=0.0)
        p1_l = p2_l / 2.0 if mean_r_l >= 0 else 1.0 - p2_l / 2.0
        print(f"  Load {load_val}: n = {len(r_vals)}, "
              f"mean r = {mean_r_l:.4f} ± {sd_r_l:.4f}, "
              f"t = {t_l:.3f}, one-sided p = {p1_l:.3e}")

    return df

# %%
trf_dir2=r"C:\Users\cdd\Documents\Uni\Special_course\code\Special_course\THESIS\eelbrain\ran6\TRF"
df_dec2 = analyze_all_decoders(trf_dir=trf_dir2)
num_below_zero = (df_dec2['r'] < 0).sum()
print(num_below_zero)
# Out:
# Collected decoder results:
#     subject  load         r  var_explained                               file
# 0        33    13  0.029522       0.077631  dec_eeg_to_ppd_sub-033_l13.pickle
# 1        34    13  0.206398       3.540083  dec_eeg_to_ppd_sub-034_l13.pickle
# 2        36    13  0.084298       0.587162  dec_eeg_to_ppd_sub-036_l13.pickle
# 3        38    13 -0.106234      -0.498336  dec_eeg_to_ppd_sub-038_l13.pickle
# 4        39    13  0.200247       2.364434  dec_eeg_to_ppd_sub-039_l13.pickle
# 5        40    13  0.217817       4.317970  dec_eeg_to_ppd_sub-040_l13.pickle
# 6        41    13  0.047415       0.181506  dec_eeg_to_ppd_sub-041_l13.pickle
# 7        42    13  0.173002       2.157504  dec_eeg_to_ppd_sub-042_l13.pickle
# 8        43    13  0.116692       1.153333  dec_eeg_to_ppd_sub-043_l13.pickle
# 9        44    13  0.108156       0.956560  dec_eeg_to_ppd_sub-044_l13.pickle
# 10       45    13 -0.022625      -0.474431  dec_eeg_to_ppd_sub-045_l13.pickle
# 11       47    13  0.027637      -0.285751  dec_eeg_to_ppd_sub-047_l13.pickle
# 12       48    13  0.169400       1.970357  dec_eeg_to_ppd_sub-048_l13.pickle
# 13       49    13  0.014779      -0.057245  dec_eeg_to_ppd_sub-049_l13.pickle
# 14       50    13  0.112847       0.793918  dec_eeg_to_ppd_sub-050_l13.pickle
# 15       51    13  0.151164       1.643983  dec_eeg_to_ppd_sub-051_l13.pickle
# 16       52    13 -0.009588      -0.174899  dec_eeg_to_ppd_sub-052_l13.pickle
# 17       54    13  0.111055       1.068645  dec_eeg_to_ppd_sub-054_l13.pickle
# 18       55    13  0.031216       0.054621  dec_eeg_to_ppd_sub-055_l13.pickle
# 19       56    13 -0.145891      -0.982685  dec_eeg_to_ppd_sub-056_l13.pickle
# 20       57    13  0.108614       0.681240  dec_eeg_to_ppd_sub-057_l13.pickle
# 21       58    13  0.124350       1.543760  dec_eeg_to_ppd_sub-058_l13.pickle
# 22       59    13  0.101231       0.970137  dec_eeg_to_ppd_sub-059_l13.pickle
# 23       62    13  0.212864       2.748374  dec_eeg_to_ppd_sub-062_l13.pickle
# 24       63    13  0.032366       0.024752  dec_eeg_to_ppd_sub-063_l13.pickle
#
# === Overall decoder r (EEG → ppd) ===
# n = 25
# mean r = 0.0839, SD = 0.0947
# t(24) = 4.427, one-sided p (r>0) = 8.923e-05
# mean % variance explained = 0.975 ± 1.316
# t(24) = 3.702, one-sided p (var explained > 0) = 5.568e-04
#
# === Per-load tests (decoder r > 0) ===
#   Load 13: n = 25, mean r = 0.0839 ± 0.0947, t = 4.427, one-sided p = 8.923e-05
# 4

# %%
trf_dir2=r"C:\Users\cdd\Documents\Uni\Special_course\code\Special_course\THESIS\eelbrain\ran7\TRF"
df_dec2 = analyze_all_decoders(trf_dir=trf_dir2)
num_below_zero = (df_dec2['r'] < 0).sum()
print(num_below_zero)
# Out:
# Collected decoder results:
#     subject  load         r  var_explained                               file
# 0        33    13  0.034412       0.081722  dec_eeg_to_ppd_sub-033_l13.pickle
# 1        34    13  0.217352       4.632193  dec_eeg_to_ppd_sub-034_l13.pickle
# 2        36    13  0.178263       2.671755  dec_eeg_to_ppd_sub-036_l13.pickle
# 3        38    13 -0.091334      -0.774820  dec_eeg_to_ppd_sub-038_l13.pickle
# 4        39    13  0.265623       5.594990  dec_eeg_to_ppd_sub-039_l13.pickle
# 5        40    13  0.117986       1.347049  dec_eeg_to_ppd_sub-040_l13.pickle
# 6        41    13  0.011444      -0.077167  dec_eeg_to_ppd_sub-041_l13.pickle
# 7        42    13  0.066268       0.385198  dec_eeg_to_ppd_sub-042_l13.pickle
# 8        43    13  0.054456       0.287476  dec_eeg_to_ppd_sub-043_l13.pickle
# 9        44    13 -0.042397      -0.434161  dec_eeg_to_ppd_sub-044_l13.pickle
# 10       45    13 -0.093299      -1.782086  dec_eeg_to_ppd_sub-045_l13.pickle
# 11       47    13  0.019612      -0.099905  dec_eeg_to_ppd_sub-047_l13.pickle
# 12       48    13  0.127416       0.923679  dec_eeg_to_ppd_sub-048_l13.pickle
# 13       49    13  0.041077      -0.122324  dec_eeg_to_ppd_sub-049_l13.pickle
# 14       50    13  0.031878       0.022916  dec_eeg_to_ppd_sub-050_l13.pickle
# 15       51    13  0.349576       5.962048  dec_eeg_to_ppd_sub-051_l13.pickle
# 16       52    13 -0.161683      -1.530408  dec_eeg_to_ppd_sub-052_l13.pickle
# 17       54    13  0.082481       0.676595  dec_eeg_to_ppd_sub-054_l13.pickle
# 18       55    13  0.064350       0.358321  dec_eeg_to_ppd_sub-055_l13.pickle
# 19       56    13 -0.055040      -0.575033  dec_eeg_to_ppd_sub-056_l13.pickle
# 20       57    13 -0.093377      -1.299248  dec_eeg_to_ppd_sub-057_l13.pickle
# 21       58    13  0.219792       3.705225  dec_eeg_to_ppd_sub-058_l13.pickle
# 22       59    13  0.149639       1.784041  dec_eeg_to_ppd_sub-059_l13.pickle
# 23       62    13  0.114589       0.828454  dec_eeg_to_ppd_sub-062_l13.pickle
# 24       63    13  0.168863       2.474055  dec_eeg_to_ppd_sub-063_l13.pickle
# 25       64    13  0.040821       0.166558  dec_eeg_to_ppd_sub-064_l13.pickle
# 26       65    13  0.287527       5.395823  dec_eeg_to_ppd_sub-065_l13.pickle
# 27       67    13  0.000696      -0.694233  dec_eeg_to_ppd_sub-067_l13.pickle
# 28       69     9  0.244486       5.879711   dec_eeg_to_ppd_sub-069_l9.pickle
# 29       70    13  0.086271       0.699114  dec_eeg_to_ppd_sub-070_l13.pickle
# 30       71    13  0.035235       0.116401  dec_eeg_to_ppd_sub-071_l13.pickle
# 31       72    13  0.087335       0.621738  dec_eeg_to_ppd_sub-072_l13.pickle
# 32       73    13  0.038617       0.054613  dec_eeg_to_ppd_sub-073_l13.pickle
# 33       74    13  0.085062       0.537335  dec_eeg_to_ppd_sub-074_l13.pickle
# 34       75    13  0.066729       0.368521  dec_eeg_to_ppd_sub-075_l13.pickle
# 35       76    13 -0.039913      -0.469208  dec_eeg_to_ppd_sub-076_l13.pickle
# 36       77    13  0.159953       1.612550  dec_eeg_to_ppd_sub-077_l13.pickle
# 37       79    13  0.058004       0.332954  dec_eeg_to_ppd_sub-079_l13.pickle
# 38       80    13  0.072068       0.465160  dec_eeg_to_ppd_sub-080_l13.pickle
# 39       81    13 -0.045253      -0.665831  dec_eeg_to_ppd_sub-081_l13.pickle
# 40       82    13 -0.084625      -0.355195  dec_eeg_to_ppd_sub-082_l13.pickle
# 41       83    13 -0.155350      -4.144209  dec_eeg_to_ppd_sub-083_l13.pickle
# 42       85    13  0.155130       2.045391  dec_eeg_to_ppd_sub-085_l13.pickle
# 43       86    13 -0.037921      -0.615313  dec_eeg_to_ppd_sub-086_l13.pickle
# 44       87    13 -0.111179      -1.022075  dec_eeg_to_ppd_sub-087_l13.pickle
# 45       88    13  0.084487       0.509020  dec_eeg_to_ppd_sub-088_l13.pickle
# 46       89    13  0.244987       4.086070  dec_eeg_to_ppd_sub-089_l13.pickle
# 47       91    13  0.230493       2.728916  dec_eeg_to_ppd_sub-091_l13.pickle
# 48       92    13  0.074718       0.550628  dec_eeg_to_ppd_sub-092_l13.pickle
# 49       93    13  0.167451       1.974269  dec_eeg_to_ppd_sub-093_l13.pickle
# 50       95     9  0.041250       0.168335   dec_eeg_to_ppd_sub-095_l9.pickle
# 51       98    13  0.115082       1.226590  dec_eeg_to_ppd_sub-098_l13.pickle
#
# === Overall decoder r (EEG → ppd) ===
# n = 52
# mean r = 0.0708, SD = 0.1157
# t(51) = 4.411, one-sided p (r>0) = 2.667e-05
# mean % variance explained = 0.896 ± 2.036
# t(51) = 3.175, one-sided p (var explained > 0) = 1.270e-03
#
# === Per-load tests (decoder r > 0) ===
#   Load 9: n = 2, mean r = 0.1429 ± 0.1437, t = 1.406, one-sided p = 1.968e-01
#   Load 13: n = 50, mean r = 0.0679 ± 0.1153, t = 4.164, one-sided p = 6.309e-05
# 12

# %%
import re
from pathlib import Path
import eelbrain
from matplotlib import pyplot as plt

# ---------------------------------------------------------------------
# Paths
# ---------------------------------------------------------------------
TRF_DIR = Path(r"C:\Users\cdd\Documents\Uni\Special_course\code\Special_course\THESIS\eelbrain\ran6\TRF")

# ---------------------------------------------------------------------
# Collect all encoding TRFs (ignore loads, keep all subjects)
# ---------------------------------------------------------------------
cases = []

for f in TRF_DIR.glob("enc_ppd_to_eeg_sub-*_l*.pickle"):
    m = re.match(r"enc_ppd_to_eeg_sub-(\d+)_l(\d+)\.pickle", f.name)
    if not m:
        continue
    
    subj = f"S{int(m.group(1)):03d}"
    print(f"Loading subject {subj} from {f.name}...")
    enc = eelbrain.load.unpickle(f)

    trf = enc.h_scaled              # NDVar(sensor × time)
    pred = enc.proportion_explained * 100  # % variance explained per sensor
    
    cases.append([subj, trf, pred])

dataset = eelbrain.Dataset.from_caselist(
    ['subject', 'trf', 'prediction_accuracy'],
    cases,
    random='subject'
)
# Out:
# Loading subject S033 from enc_ppd_to_eeg_sub-033_l13.pickle...
# Loading subject S034 from enc_ppd_to_eeg_sub-034_l13.pickle...
# Loading subject S036 from enc_ppd_to_eeg_sub-036_l13.pickle...
# Loading subject S038 from enc_ppd_to_eeg_sub-038_l13.pickle...
# Loading subject S039 from enc_ppd_to_eeg_sub-039_l13.pickle...
# Loading subject S040 from enc_ppd_to_eeg_sub-040_l13.pickle...
# Loading subject S041 from enc_ppd_to_eeg_sub-041_l13.pickle...
# Loading subject S042 from enc_ppd_to_eeg_sub-042_l13.pickle...
# Loading subject S043 from enc_ppd_to_eeg_sub-043_l13.pickle...
# Loading subject S044 from enc_ppd_to_eeg_sub-044_l13.pickle...
# Loading subject S045 from enc_ppd_to_eeg_sub-045_l13.pickle...
# Loading subject S047 from enc_ppd_to_eeg_sub-047_l13.pickle...
# Loading subject S048 from enc_ppd_to_eeg_sub-048_l13.pickle...
# Loading subject S049 from enc_ppd_to_eeg_sub-049_l13.pickle...
# Loading subject S050 from enc_ppd_to_eeg_sub-050_l13.pickle...
# Loading subject S051 from enc_ppd_to_eeg_sub-051_l13.pickle...
# Loading subject S052 from enc_ppd_to_eeg_sub-052_l13.pickle...
# Loading subject S054 from enc_ppd_to_eeg_sub-054_l13.pickle...
# Loading subject S055 from enc_ppd_to_eeg_sub-055_l13.pickle...
# Loading subject S056 from enc_ppd_to_eeg_sub-056_l13.pickle...
# Loading subject S057 from enc_ppd_to_eeg_sub-057_l13.pickle...
# Loading subject S058 from enc_ppd_to_eeg_sub-058_l13.pickle...
# Loading subject S059 from enc_ppd_to_eeg_sub-059_l13.pickle...
# Loading subject S062 from enc_ppd_to_eeg_sub-062_l13.pickle...
# Loading subject S063 from enc_ppd_to_eeg_sub-063_l13.pickle...

# %%
from matplotlib import pyplot as plt
import eelbrain

PRED_VMAX = 1.0  # % variance explained, adjust if needed

plt.figure()
p_pow = eelbrain.plot.Topomap(
    'prediction_accuracy',
    data=dataset,
    vmax=PRED_VMAX,
    cmap='lux-gray',
    clip='circle',
)
p_pow.plot_colorbar(label="% variance explained")
plt.title("Pupil → frontal EEG: predictive power (all subjects)")
# Out:
# Text(0.5, 1.0, 'Pupil → frontal EEG: predictive power (all subjects)')

# %%
trf0 = trf_all[0]  # NDVar(sensor × time)
print(trf0)
# Out:
# <NDVar 'trf': 17 sensor, 624 time>

# %%
trf_all = dataset['trf']  # NDVar: case × sensor × time
trf_mean = trf_all.mean('case')  # NDVar: sensor × time

plt.figure()
pb = eelbrain.plot.Butterfly(
    trf_all,
    vmin=-0.0, vmax=0.005,     # adjust to your scale
    linewidth=0.5,
    color="#707070",
    frame='t',
    ylabel="TRF weight (a.u.)",
    clip=True,
)
plt.title("Pupil → frontal EEG TRFs (all subjects)")
# Out:
# Text(0.5, 1.0, 'Pupil → frontal EEG TRFs (all subjects)')

# %%
from matplotlib import pyplot as plt
import eelbrain

trf_all = dataset['trf']  # NDVar: case × sensor × time
trf_mean_sensor = trf_all.mean('sensor')  # NDVar: sensor × time


plt.figure()
eelbrain.plot.UTSStat(
    trf_mean_sensor,
    error='sem',
    frame='t',
    ylabel='TRF weight (a.u.)',
    xlabel='Time [s]',
    axtitle=f"ALL: ppd → EEG TRF (mean ± SEM)",
)
plt.show()

for name in trf_all.sensor:
    trf_s = trf_all.sub(sensor=name)  # case × time

    plt.figure()
    eelbrain.plot.UTSStat(
        trf_s,
        error='sem',
        frame='t',
        ylabel='TRF weight (a.u.)',
        xlabel='Time [s]',
        axtitle=f"{name}: ppd → EEG TRF (mean ± SEM)",
    )
    plt.show()

# %%
from pathlib import Path
import re
import numpy as np
import eelbrain
from matplotlib import pyplot as plt

TRF_DIR = Path(r"C:\Users\cdd\Documents\Uni\Special_course\code\Special_course\THESIS\eelbrain\ran7\TRF")

cases = []
for f in TRF_DIR.glob("dec_eeg_to_ppd_sub-*_l*.pickle"):
    m = re.match(r"dec_eeg_to_ppd_sub-(\d+)_l(\d+)\.pickle", f.name)
    if not m:
        continue
    subj = f"S{int(m.group(1)):03d}"
    load_val = int(m.group(2))

    dec = eelbrain.load.unpickle(f)

    trf = dec.h_scaled                     # NDVar(sensor × time): decoder weights
    r_val = float(dec.r)                   # scalar correlation
    ve = float(dec.proportion_explained) * 100  # % variance explained

    cases.append([subj, load_val, trf, r_val, ve])

dataset_dec = eelbrain.Dataset.from_caselist(
    ['subject', 'load', 'trf_dec', 'r', 'var_explained'],
    cases,
    random='subject'
)

print(f"Loaded {len(dataset_dec)} decoder results.")
# Out:
# Loaded 5 decoder results.

# %%
import numpy as np

rs = np.array(dataset_dec['r'])
print(f"Decoder r: mean={rs.mean():.4f}, SD={rs.std(ddof=1):.4f}, n={len(rs)}")

plt.figure()
plt.hist(rs, bins=10, edgecolor='black')
plt.xlabel("decoder r (EEG → pupil)")
plt.ylabel("count")
plt.title("Distribution of decoder r across subjects")
plt.show()
# Out:
# Decoder r: mean=0.0708, SD=0.1157, n=52

# %%
trf_all_dec = dataset_dec['trf_dec']  # NDVar(case × sensor × time)

plt.figure()
pb_dec = eelbrain.plot.Butterfly(
    trf_all_dec,
    vmin=-0.0002, vmax=0.00035,   # adjust to your scale if needed
    linewidth=0.5,
    color='#707070',
    frame='t',
    ylabel="Decoder weight (a.u.)",
    clip=True,
)
plt.title("EEG → pupil decoder TRFs (all subjects)")

plt.show()

# %%
# mean over case dimension: sensor × time
trf_mean_dec = trf_all_dec.mean('case')

# choose times where you expect strong decoder weights
times_topo = [0.5, 1.0, 1.5]  # seconds
labels_topo = [f"{int(t*1000)} ms" for t in times_topo]

# build list of sensor NDVars, one per time
slices = [trf_mean_dec.sub(time=t) for t in times_topo]

# one figure with 3 topomaps
plt.figure()
p_topo_dec = eelbrain.plot.Topomap(
    slices,
    axtitle=labels_topo,
    vmax=0.0001,          # same as butterfly vmin/vmax
    clip='circle',
)
p_topo_dec.plot_colorbar(
    label="Decoder weight",
    ticks={0.0001: '+', -0.0001: '-', 0: '0'}
)
plt.suptitle("EEG → pupil decoder weights at selected lags")
plt.show()

# %%
# ------------------------------------------------------------
# 1) TRF per subject (average over sensors)
# ------------------------------------------------------------
trf_subj = trf_all_dec.mean('sensor')  # NDVar: case × time

plt.figure()
pb_subj = eelbrain.plot.Butterfly(
    trf_subj,
    linewidth=0.8,
    color='#707070',
    frame='t',
    clip=True,
)
plt.title("EEG → pupil decoder TRFs\n(one per subject, averaged over sensors)")
plt.ylabel("Decoder weight (a.u.)")
plt.show()

# %%
# trf_subj: NDVar(case × time), one TRF per subject (already computed)
trf_subj = trf_all_dec.mean('sensor')

for i, subj_label in enumerate(dataset_dec['subject']):
    plt.figure()
    eelbrain.plot.UTS(
        trf_subj[i],     # NDVar(time) for this subject
        frame='t',
        color='k',
        #linewidth=1.5,
    )
    plt.ylim(-0.0003, 0.00025)  # adjust to your scale   
    plt.title(f"EEG → pupil decoder TRF\n{str(subj_label)} (averaged over sensors)")
    plt.ylabel("Decoder weight (a.u.)")
    plt.xlabel("Time (s)")
    plt.tight_layout()
    # Optional: save instead of (or in addition to) showing
    # out_path = TRF_DIR / f"dec_TRF_{subj_label}.png"
    # plt.savefig(out_path, dpi=150)
    # plt.close()

plt.show()  # if you didn’t close figures in the loop
# Out:
# C:\Users\cdd\AppData\Local\Temp\ipykernel_20304\3960827057.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()

# %%
# ------------------------------------------------------------
# 2) TRF per sensor (average over subjects)
# ------------------------------------------------------------
trf_sens = trf_all_dec.mean('case')  # NDVar: sensor × time

plt.figure()
pb_sens = eelbrain.plot.Butterfly(
    trf_sens,
    linewidth=0.8,
    color='#707070',
    frame='t',
    clip=True,
)
plt.title("EEG → pupil decoder TRFs\n(one per sensor, averaged over subjects)")
plt.ylabel("Decoder weight (a.u.)")
plt.show()

# pick a time point (in seconds)
latency = 0  # adjust as needed
trf_at_lat = trf_sens.sub(time=latency)

eelbrain.plot.Topomap(
    trf_at_lat,
    vmin=-0.0002,
    vmax=0.00035,
)
plt.title(f"Decoder weights at {latency:.3f} s")
plt.show()

# %%
# trf_subj: NDVar(case × time), one TRF per subject (already computed)
trf_sensor = trf_all_dec.mean('sensor')

plt.figure()
eelbrain.plot.UTSStat(
    trf_sensor,
    error='sem',
    frame='t',
    ylabel='TRF weight (a.u.)',
    xlabel='Time [s]',
    axtitle=f"ALL: ppd → EEG TRF (mean ± SEM)",
)
plt.show()

for name in trf_all_dec.sensor:
    trf_s = trf_all_dec.sub(sensor=name)  # case × time

    plt.figure()
    eelbrain.plot.UTSStat(
        trf_s,
        error='sem',
        frame='t',
        ylabel='TRF weight (a.u.)',
        xlabel='Time [s]',
        axtitle=f"{name}: ppd → EEG TRF (mean ± SEM)",
    )
    plt.ylim(-0.0001, 0.0001)  # adjust to your scale
    plt.show()
