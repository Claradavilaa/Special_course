# %%
# %reset -f

# %%
from __future__ import annotations
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.cross_decomposition import CCA
#from mvlearn.embed import CCA # for this one i need to put cca.xxx([Xp_train, Yp_train]) insetad of cca.xxx(Xp_train, Yp_train)
from scipy.stats import pearsonr 
from scipy import stats

###############################################################################
# Paths & constants
###############################################################################
PUPIL_ROOT = Path(r"C:\Users\cdd\Documents\Uni\Special_course\pupil_processed_clara")
EEG_ROOT   = Path(r"C:\Users\cdd\Documents\Uni\Special_course\code\Special_course\eeg_theta_processed2")

FRONTAL_MIDLINE = ['AFz','AF3','AF4','Fz','F1','F2','F3','F4','FC3','FC1','FC2','FC4','Cz','C3','C1','C2','C4']

OUT_TRIALS  = Path("trial_level_cca_fixedlag.csv")
OUT_SUBJECT = Path("subject_best_lag.csv")

SUBJECTS = np.setdiff1d(np.arange(32, 99), [32, 37, 53, 61, 66, 78, 84, 90, 94, 96])
#SUBJECTS = np.setdiff1d(np.arange(32, 99), [32, 37, 53, 61, 66, 78, 84, 90, 94, 96])
SHIFTS = np.arange(-100, 101)      # ±1 s at 100 Hz → samples
WIN_OFFSET1 = 200                  # discard first 200 ms
WIN_OFFSET2 = 110                  # discard last 110 ms

###############################################################################
# Helper functions
###############################################################################

def normalise_eeg(x: np.ndarray) -> np.ndarray:
    """Centre each channel and scale so Σ x² = 1 over time×channels."""
    x = x - x.mean(axis=0, keepdims=True)
    scale = np.sqrt(np.mean(x**2))
    return x / scale


def cca_corr(eeg: np.ndarray, pupil: np.ndarray) -> float:
    """Canonical correlation (single component)."""
    cca = CCA(n_components=1, max_iter=1000, scale=False, tol=1e-6)
    cca.fit(eeg, pupil)
    u, v = cca.transform(eeg, pupil)
    return float(np.corrcoef(u[:, 0], v[:, 0])[0, 1])

# %%
def load_all_trials(
        sub: int,
        eeg_root: Path = EEG_ROOT,
        pupil_root: Path = PUPIL_ROOT,
        min_len: int = 40,
        max_len_diff: int = 30,
) -> list[tuple[np.ndarray, np.ndarray, dict]]:
    """
    Load *all* valid EEG-pupil trial pairs for one subject.

    Parameters
    ----------
    sub : int
        Numeric subject ID (e.g. 42).
    eeg_root, pupil_root : Path
        Roots of the pre-processed EEG and pupil folders.
    min_len : int
        Minimum number of samples a pupil trace must have to be accepted.
    max_len_diff : int
        Reject trial if |len(pupil)-len(eeg)| exceeds this.
    Returns
    -------
    trials : list of (eeg, pupil_z, meta)
        * eeg        - (T × n_channels) float64, already centred/scaled
        * pupil_z    - (T × 1) float64, per-trial z-scored
        * meta       - dict with subject/condition/load/epoch
    """
    trials = []
    sub_tag = f"sub-{sub:03d}"
    eeg_sub  = eeg_root   / sub_tag
    pupil_sub = pupil_root / sub_tag

    if not eeg_sub.exists():
        print(f"{sub_tag}: EEG folder missing - skipped")
        return trials

    # iterate condition (“control” / “memory”) and load (“05” / “09” / “13”)
    for cond_path in sorted(eeg_sub.iterdir()):
        if not cond_path.is_dir():
            continue
        for load_path in sorted(cond_path.iterdir()):
            if not load_path.is_dir():
                continue

            # matching pupil directory
            pupil_path = pupil_sub / cond_path.name / load_path.name
            if not pupil_path.exists():
                continue

            eeg_epochs   = sorted(load_path.glob("trial_*.csv"))
            pupil_epochs = sorted(pupil_path.glob("trial_*.csv"))
            common = {f.name for f in eeg_epochs} & {f.name for f in pupil_epochs}
            if not common:
                continue

            for fname in sorted(common):
                eeg_df = pd.read_csv(load_path / fname, comment="#", index_col=0)
                pupil_df = pd.read_csv(pupil_path / fname, comment="#",
                                       names=["time", "diameter_z"], index_col=0)

                eeg   = eeg_df.values.astype(float)
                pupil = pupil_df["diameter_z"].values.astype(float)

                # basic validity checks
                if len(pupil) < min_len or abs(len(pupil) - len(eeg)) > max_len_diff:
                    continue

                # normalise signals ----------------------------------------
                eeg_norm = normalise_eeg(eeg)           # your helper from before
                pupil_z  = ((pupil - pupil.mean()) / pupil.std(ddof=0))

                # same number of samples
                T = min(len(eeg_norm), len(pupil_z))
                eeg_norm = eeg_norm[0:T, :]  # (T × n_channels)
                pupil_z  = pupil_z[0:T].reshape(-1, 1)

                meta = {
                    "subject":   sub_tag,
                    "condition": cond_path.name,
                    "load":      int(load_path.name),
                    "epoch":     fname
                }
                trials.append((eeg_norm, pupil_z, meta))

    return trials

from typing import List, Tuple
import numpy as np

def split_trials_by_condition(
        trials: List[Tuple[np.ndarray, np.ndarray, dict]],
        memory_label: str = "memory",
        control_label: str = "control"
) -> Tuple[List[Tuple[np.ndarray, np.ndarray, dict]], List[Tuple[np.ndarray, np.ndarray, dict]]]:
    """
    Separate a mixed list of (eeg, pupil, meta) trial tuples into memory-condition and control-condition sub-lists.

    Parameters
    ----------
    trials : list of tuples
        Each tuple = (eeg_array, pupil_array, meta_dict).
        meta_dict must contain a key 'condition'.
    memory_label : str
        The value of meta['condition'] that marks a memory trial.
    control_label : str
        The value of meta['condition'] that marks a control trial.

    Returns
    -------
    memory_trials  : list[tuple]
    control_trials : list[tuple]
    """
    memory_trials  = []
    control_trials = []

    for eeg, pupil, meta in trials:
        cond = meta.get("condition", "").lower()
        if cond == memory_label:
            memory_trials.append((eeg, pupil, meta))
        elif cond == control_label:
            control_trials.append((eeg, pupil, meta))
        else: raise ValueError(f"Unknown condition label: {cond}")

    return memory_trials, control_trials

def split_trials_by_load(trials: List[Tuple[np.ndarray, np.ndarray, dict]]
                         ) -> Tuple[List[Tuple[np.ndarray, np.ndarray, dict]], List[Tuple[np.ndarray, np.ndarray, dict]], List[Tuple[np.ndarray, np.ndarray, dict]]]:
    """
    Separate a mixed list of (eeg, pupil, meta) trial tuples into 05, 09 and 13 load sub-lists.

    Parameters
    ----------
    trials : list of tuples
        Each tuple = (eeg_array, pupil_array, meta_dict).
        meta_dict must contain a key 'load'.

    Returns
    -------
    load_05_trials  : list[tuple]
    load_09_trials  : list[tuple]
    load_13_trials  : list[tuple]
    """
    load_05_trials = []
    load_09_trials = []
    load_13_trials = []

    for eeg, pupil, meta in trials:
        load = meta.get("load")
        if load == 5:
            load_05_trials.append((eeg, pupil, meta))
        elif load == 9:
            load_09_trials.append((eeg, pupil, meta))
        elif load == 13:
            load_13_trials.append((eeg, pupil, meta))
        else: raise ValueError(f"Unknown load label: {load}")

    return load_05_trials, load_09_trials, load_13_trials

# %%
import numpy as np
from typing import List, Tuple, Dict

def search_best_lag(
        train_trials: List[Tuple[np.ndarray, np.ndarray, dict]],
        shifts: np.ndarray = SHIFTS,
        return_curve: bool = False
) -> Tuple[float, int, Dict[int, float] | None]:
    """
    Search for the lag (sample shift) that maximises the mean canonical
    correlation between EEG and pupil traces in a training set.

    Parameters
    ----------
    train_trials : list of (eeg, pupil_z, meta)
        Each eeg  : 2-D array [time × channels or CCA-components]
        Each pupil: 1-D array [time]
    shifts : np.ndarray
        Array of integer lag shifts (positive = EEG is moved forward).
    return_curve : bool, default False
        If True, also return the full {shift: mean_r} dictionary.

    Returns
    -------
    best_corr : float
        Highest mean canonical correlation found.
    best_shift : int
        Shift (samples) that maximised the correlation.
    mean_r_per_shift : dict | None
        Only when `return_curve` is True.
    """
    win = slice(WIN_OFFSET1, -WIN_OFFSET2)         # common window
    mean_r_per_shift: Dict[int, float] = {}

    for s in shifts:                               # <-- loop over *shifts*, not SHIFTS
        rs = []
        for eeg, pupil_z, _ in train_trials:
            eeg_shifted = np.roll(eeg, s, axis=0)[win]
            r = cca_corr(eeg_shifted, pupil_z[win])
            rs.append(r)
        mean_r_per_shift[s] = float(np.mean(rs))   # cast to plain float for JSON-ability

    best_shift = max(mean_r_per_shift, key=mean_r_per_shift.get)
    best_corr  = mean_r_per_shift[best_shift]

    if return_curve:
        return best_corr, best_shift, mean_r_per_shift
    else:
        return best_corr, best_shift, None

# %%
from typing import List, Tuple, Optional

# trials  : list of (eeg, pupil_z, meta)   -- the tuples returned by load_all_trials
# shift   : integer sample shift (best_shift)
# win     : slice or None                  -- cropping window (set to None if the
#                                            trials are already pre-trimmed)
def concat_trials(
        trials: List[Tuple[np.ndarray, np.ndarray, dict]],
        shift: int = 0,
        win: Optional[slice] = None
) -> Tuple[np.ndarray, np.ndarray]:
    """
    Concatenate a list of trials into one long matrix pair ready for CCA.

    Returns
    -------
    X  : ndarray, shape (Σ Tᵢ, n_channels)
    Y  : ndarray, shape (Σ Tᵢ, 1)
    """
    X_blocks, Y_blocks = [], []

    for eeg, pupil_z, _ in trials:
        # 1. roll *inside* the trial so samples never cross trial boundaries
        eeg_shift = np.roll(eeg, shift, axis=0)

        # 2. optional windowing (do it once here if you did **not** crop in loader)
        if win is not None:
            eeg_shift = eeg_shift[win]
            pupil_seg = pupil_z[win]
        else:
            pupil_seg = pupil_z          # already trimmed earlier

        # 3. stack
        X_blocks.append(eeg_shift)
        Y_blocks.append(pupil_seg)

    X = np.vstack(X_blocks)
    Y = np.vstack(Y_blocks)
    return X, Y

def iterate_trials(trials, shift, win):
    """Yield (eeg_shifted, pupil_z_windowed, meta) one by one."""
    for eeg, pupil_z, meta in trials:
        eeg_s = np.roll(eeg, shift, axis=0)[win]
        yield eeg_s, pupil_z[win], meta.copy()

import pandas as pd
import json
from pathlib import Path

def save_cca_weights(cca, subject_tag, lag_ms, eeg_ch_names, condition, out_dir=Path("weights")):
    """
    Dump EEG & pupil canonical weights to CSV/JSON for one subject.

    Parameters
    ----------
    cca            : fitted sklearn.cross_decomposition.CCA
    subject_tag    : "sub-042"
    lag_ms         : e.g. -90
    eeg_ch_names   : list[str] same order as columns in your trial matrices
    out_dir        : destination folder (created if missing)
    """
    out_dir.mkdir(parents=True, exist_ok=True)

    # ------- Pupil weight -> JSON ---------------------------------------
    w_pupil_og = float(cca.y_weights_[0, 0])   # scalar in 1-dim pupil case
    w_pupil = 1.0
    with open(out_dir / f"{subject_tag}_pupil_weight_{condition}_{lag_ms:+d}ms.json", "w") as fh:
        json.dump({"weight": w_pupil}, fh, indent=2)
    
    # ------- EEG weights -> tidy CSV ------------------------------------
    w_eeg = cca.x_weights_[:, 0] / w_pupil_og
    w_eeg = pd.Series(w_eeg, index=eeg_ch_names, name="weight")
    w_eeg.index.name = "channel"
    w_eeg.to_csv(out_dir / f"{subject_tag}_eeg_weights_{condition}_{lag_ms:+d}ms.csv")

    print(f"saved weights for {subject_tag} (lag {lag_ms:+d} ms)")

# %%
best_shift_by_sub = {33: -5, 34: 32, 35: -8, 36: -59, 38: -1, 39: 2, 40: 100, 41: -10, 42: -80, 43: 70, 44: -10, 45: 42, 46: -68, 47: 100, 48: -63, 49: 46, 50: 91, 51: 100, 52: 81, 54: 63, 55: -38, 56: 23, 57: 36, 58: 46, 59: -7, 60: 100, 62: -9, 63: 0, 64: 53, 65: -6, 67: 2, 68: 96, 69: 28, 70: 16, 71: 74, 72: 0, 73: 38, 74: -100, 75: 32, 76: 100, 77: 76, 79: 80, 80: -1, 81: 64, 82: -44, 83: -52, 85: 37, 86: 100, 87: 24, 88: 100, 89: -100, 91: -5, 92: 41, 93: 100, 95: -7, 97: -56, 98: 69}
print(best_shift_by_sub)
# Out:
# {33: -5, 34: 32, 35: -8, 36: -59, 38: -1, 39: 2, 40: 100, 41: -10, 42: -80, 43: 70, 44: -10, 45: 42, 46: -68, 47: 100, 48: -63, 49: 46, 50: 91, 51: 100, 52: 81, 54: 63, 55: -38, 56: 23, 57: 36, 58: 46, 59: -7, 60: 100, 62: -9, 63: 0, 64: 53, 65: -6, 67: 2, 68: 96, 69: 28, 70: 16, 71: 74, 72: 0, 73: 38, 74: -100, 75: 32, 76: 100, 77: 76, 79: 80, 80: -1, 81: 64, 82: -44, 83: -52, 85: 37, 86: 100, 87: 24, 88: 100, 89: -100, 91: -5, 92: 41, 93: 100, 95: -7, 97: -56, 98: 69}

# %% [markdown]
# ### training and testing on all

# %%
import random
from math import atanh, sqrt
from scipy.stats import norm, ttest_rel, wilcoxon

import matplotlib.pyplot as plt

all_rows = []  # collect all trial-level results here
# best_shift_by_sub = {}  # best shift per subject
rows_trials = []
rows_subject = []  
bad_subjects_mem = []
bad_subjects_ctrl = []

for subj in SUBJECTS:
    if subj == 57:
        continue
    print(f"Processing subject {subj:02d}...")
    trials = load_all_trials(subj)                         # list of (eeg, pupil)
    trials_memory, trials_control = split_trials_by_condition(trials)

    random.shuffle(trials_memory)
    random.shuffle(trials_control)

    trials_mem_05, trials_mem_09, trials_mem_13 = split_trials_by_load(trials_memory)
    trials_ctrl_05, trials_ctrl_09, trials_ctrl_13 = split_trials_by_load(trials_control)

    if len(trials_mem_05) < 2 or len(trials_mem_09) < 2 or len(trials_mem_13) < 2 or len(trials_ctrl_05) < 2 or len(trials_ctrl_09) < 2 or len(trials_ctrl_13) < 2:
        print(f"Subject {subj:02d} skipped - not enough trials in one of the load conditions.")
        continue

    mid_mem_05 = int(len(trials_mem_05) // 2)
    mid_mem_09 = int(len(trials_mem_09) // 2)
    mid_mem_13 = int(len(trials_mem_13) // 2)

    mid_ctrl_05 = int(len(trials_ctrl_05) // 2)
    mid_ctrl_09 = int(len(trials_ctrl_09) // 2)
    mid_ctrl_13 = int(len(trials_ctrl_13) // 2)

    train_memory = trials_mem_05[:mid_mem_05] + trials_mem_09[:mid_mem_09] + trials_mem_13[:mid_mem_13]
    test_memory  = trials_mem_05[mid_mem_05:] + trials_mem_09[mid_mem_09:] + trials_mem_13[mid_mem_13:]
    train_control = trials_ctrl_05[:mid_ctrl_05] + trials_ctrl_09[:mid_ctrl_09] + trials_ctrl_13[:mid_ctrl_13]
    test_control = trials_ctrl_05[mid_ctrl_05:] + trials_ctrl_09[mid_ctrl_09:] + trials_ctrl_13[mid_ctrl_13:]

    train_trials = train_memory + train_control
    random.shuffle(train_trials)

    best_shift = best_shift_by_sub[subj] if subj in best_shift_by_sub else print("MISTAKE")
    # ----- fit weights ONCE using all train trials at best_shift ---------
    win = slice(WIN_OFFSET1, -WIN_OFFSET2)

    best_shift = int(best_shift)  # convert to int if it was float
    X_train, Y_train = concat_trials(train_trials, shift=best_shift, win=win)
    X_mem_test, Y_mem_test = concat_trials(test_memory, shift=best_shift, win=win)
    X_ctrl_test, Y_ctrl_test = concat_trials(test_control, shift=best_shift, win=win)

    # --- fit CCA  ---
    cca = CCA(n_components=1, max_iter=1000, scale=False, tol=1e-6)
    cca.fit(X_train, Y_train)

    # --- transform MEMORY set  ---
    cvX_m, cvY_m = cca.transform(X_mem_test, Y_mem_test)
    r_mem, p_mem = pearsonr(cvX_m[:, 0], cvY_m[:, 0])

    # --- transform CONTROL set  ---
    cvX_c, cvY_c = cca.transform(X_ctrl_test, Y_ctrl_test)
    r_ctrl, p_ctrl = pearsonr(cvX_c[:, 0], cvY_c[:, 0])

    rows_subject.append({ 
        "subject": subj, 
        "condition": "memory", 
        "lag_ms": best_shift * 10, 
        "r": float(r_mem),
        "p-value": float(p_mem)
    })

    rows_subject.append({ 
        "subject": subj, 
        "condition": "control", 
        "lag_ms": best_shift * 10, 
        "r": float(r_ctrl),
        "p-value": float(p_ctrl)
    })

    n_mem  = cvX_m.shape[0]  # number of paired points used in r_mem
    n_ctrl = cvX_c.shape[0]  # number of paired points used in r_ctrl

    z_mem  = atanh(r_mem)
    z_ctrl = atanh(r_ctrl)

    # z-test for H1: r_mem > r_ctrl
    se = sqrt(1/(n_mem - 3) + 1/(n_ctrl - 3))
    z_stat = (z_mem - z_ctrl) / se
    p_one_sided = 1 - norm.cdf(z_stat)

    rows_subject.append({
        "subject": subj,
        "condition": "per-subject test",
        "lag_ms": best_shift * 10,
        "r_mem": float(r_mem),
        "r_ctrl": float(r_ctrl),
        "n_mem": int(n_mem),
        "n_ctrl": int(n_ctrl),
        "z_stat": float(z_stat),
        "p_one_sided": float(p_one_sided),
    })

    if p_ctrl > 0.05:
        bad_subjects_ctrl.append(subj)
    if p_mem > 0.05:
        bad_subjects_mem.append(subj)
    if p_mem > 0.05 and p_ctrl > 0.05:
        print(f"Subject {subj:02d} has both p_mem and p_ctrl > 0.05")

    save_cca_weights(cca, subject_tag=f"sub-{subj:03d}", lag_ms=best_shift*10, condition = "mem", eeg_ch_names=FRONTAL_MIDLINE, out_dir=Path("weights_HoldStratLoad"))

##############################################################################
# ---- save -----------------------------------------------------------------
##############################################################################

##############################################################################
# 4)  after the loop - save per‑subject correlations
##############################################################################
pd.DataFrame(rows_subject).to_csv("subject_level_cca_fixedlagTHESISAll.csv", index=False)
print("Finished - saved subject-level correlations as subject_level_cca_fixedlagTHESISAll.csv.")
# Out:
# Processing subject 33...
# saved weights for sub-033 (lag -50 ms)
# Processing subject 34...
# saved weights for sub-034 (lag +320 ms)
# Processing subject 35...
# Subject 35 skipped - not enough trials in one of the load conditions.
# Processing subject 36...
# saved weights for sub-036 (lag -590 ms)
# Processing subject 38...
# saved weights for sub-038 (lag -10 ms)
# Processing subject 39...
# saved weights for sub-039 (lag +20 ms)
# Processing subject 40...
# saved weights for sub-040 (lag +1000 ms)
# Processing subject 41...
# saved weights for sub-041 (lag -100 ms)
# Processing subject 42...
# saved weights for sub-042 (lag -800 ms)
# Processing subject 43...
# saved weights for sub-043 (lag +700 ms)
# Processing subject 44...
# saved weights for sub-044 (lag -100 ms)
# Processing subject 45...
# saved weights for sub-045 (lag +420 ms)
# Processing subject 46...
# Subject 46 skipped - not enough trials in one of the load conditions.
# Processing subject 47...
# saved weights for sub-047 (lag +1000 ms)
# Processing subject 48...
# saved weights for sub-048 (lag -630 ms)
# Processing subject 49...
# saved weights for sub-049 (lag +460 ms)
# Processing subject 50...
# saved weights for sub-050 (lag +910 ms)
# Processing subject 51...
# saved weights for sub-051 (lag +1000 ms)
# Processing subject 52...
# saved weights for sub-052 (lag +810 ms)
# Processing subject 54...
# saved weights for sub-054 (lag +630 ms)
# Processing subject 55...

# %%
df = pd.DataFrame(rows_subject)

# keep one row per subject per condition
wide = (df.query("condition in ['memory','control']")
          .pivot(index="subject", columns="condition", values="r"))

# subjects with non-significant per-subject test (p_one_sided > 0.05)
bad_subjects = df.loc[
    (df["condition"] == "per-subject test") & (df["p_one_sided"] > 0.05),
    "subject"
].unique()

print("There are", len (SUBJECTS) - len(bad_subjects), "subjects with significant per-subject test (p_one_sided < 0.05)")

# keep everyone else and make the wide table
wide2 = (df[~df["subject"].isin(bad_subjects)]
          .query("condition in ['memory','control']")
          .pivot(index="subject", columns="condition", values="r"))

# Fisher z
z_mem  = np.arctanh(wide["memory"])
z_ctrl = np.arctanh(wide["control"])
diff   = z_mem - z_ctrl

# one-sided paired t-test: H1 mean(diff) > 0
t2, p_two = ttest_rel(z_mem, z_ctrl, nan_policy='omit')
# convert to one-sided
p_one = p_two / 2 if diff.mean() > 0 else 1 - p_two/2

# (optional) distribution-free paired test on r (or z):
w_stat, p_wilcox_two = wilcoxon(z_mem, z_ctrl, alternative="greater", zero_method="wilcox", correction=False)

print({
    "mean_diff_z": float(np.nanmean(diff)),
    "t_stat": float(t2),
    "p_one_sided_t": float(p_one),
    "wilcoxon_W": float(w_stat),
    "p_one_sided_wilcoxon": float(p_wilcox_two),
    "n_subjects": int(diff.dropna().shape[0]),
})

# %%
df_subj = pd.read_csv("subject_level_cca_fixedlagTHESISAll.csv")

# Calculate and print mean correlations for each condition
mean_memory = df_subj[df_subj['condition'] == 'memory']['r'].mean()
mean_control = df_subj[df_subj['condition'] == 'control']['r'].mean()
print(f"Mean correlation for memory condition: {mean_memory:.4f}")
print(f"Mean correlation for control condition: {mean_control:.4f}")
print()

# Pivot so we have columns for memory and control per subject
df_wide = df_subj.pivot(index="subject", columns="condition", values="r")
print(df_wide.head(20))

# --- 95% CI for the paired mean difference (mem − ctl) ---
paired = df_wide.dropna(subset=["memory", "control"])
diff   = paired["memory"] - paired["control"]

n      = diff.size
dfree  = n - 1
mean_d = diff.mean()
se_d   = diff.std(ddof=1) / np.sqrt(n)

alpha  = 0.05
tcrit  = stats.t.ppf(1 - alpha/2, dfree)   # two-sided 95%
ci_low, ci_high = mean_d - tcrit*se_d, mean_d + tcrit*se_d

# (optional) re-run t-test on the same paired subset
t2, p2 = stats.ttest_rel(paired["memory"], paired["control"])
p_one  = p2/2 if t2 > 0 else 1 - p2/2

print(f"Paired t-test: t={t2:.3f}, p_two={p2:.4f}, "
      f"p_one(mem>ctl)={p_one:.4f}, df={dfree}, "
      f"meanΔ={mean_d:.3f}, 95% CI=[{ci_low:.3f}, {ci_high:.3f}]")

# %% [markdown]
# ### Now with k folds (k = 3) and stratifying condition and load

# %%
import numpy as np
rng = np.random.RandomState(42)  # reproducible shuffles

def _trial_tag(x):
    """Best-effort short tag for printing a trial object without huge dumps."""
    for attr in ("trial_id", "id", "name"):
        if hasattr(x, attr):
            return f"{attr}={getattr(x, attr)}"
    # fallback: try tuple-like or object id
    try:
        return f"tuple0={x[0]!r}"
    except Exception:
        return f"obj@{hex(id(x))}"

def _chunk_k(lst, k, rng):
    """Shuffle lst and split into k chunks (as even as possible), purely in Python."""
    idx = list(range(len(lst)))
    rng.shuffle(idx)
    shuffled = [lst[i] for i in idx]
    n = len(shuffled)
    base, rem = divmod(n, k)
    chunks, start = [], 0
    for f in range(k):
        size = base + (1 if f < rem else 0)
        chunks.append(shuffled[start:start+size])
        start += size
    return chunks

def stratified_kfold_trials(trials_memory, trials_control, k=3, verbose=True, show_examples=2):
    """
    Stratified K-fold by condition × load. Returns a list of fold dicts:
      {"train_memory", "test_memory", "train_control", "test_control"}.
    Debug prints show bucket counts, chunk sizes, per-fold sizes, and integrity checks.
    """
    # --- split memory/control by load ---
    tm05, tm09, tm13 = split_trials_by_load(trials_memory)
    tc05, tc09, tc13 = split_trials_by_load(trials_control)

    buckets = {
        ("memory", 5): list(tm05), ("memory", 9): list(tm09), ("memory", 13): list(tm13),
        ("control", 5): list(tc05), ("control", 9): list(tc09), ("control", 13): list(tc13),
    }

    order = [("memory",5),("memory",9),("memory",13),("control",5),("control",9),("control",13)]

    if verbose:
        print("\n[Bucket counts]")
        for key in order:
            print(f"  {key}: {len(buckets[key])}")

    # need at least k trials per bucket so each fold gets ≥1 in its test
    too_small = [key for key in buckets if len(buckets[key]) < k]
    if too_small:
        if verbose:
            print(f"[WARN] Not enough trials for k={k} in buckets: {too_small}. Returning [].")
        return []

    # --- split each bucket into k chunks ---
    parts = {key: _chunk_k(buckets[key], k, rng) for key in buckets}

    if verbose:
        print("\n[Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)")
        for key in order:
            sizes = [len(ch) for ch in parts[key]]
            print(f"  {key}: sizes={sizes}  total={sum(sizes)}")
            # optional: show example trial tags from first chunk
            if show_examples and len(parts[key][0]) > 0:
                ex = ", ".join(_trial_tag(t) for t in parts[key][0][:show_examples])
                print(f"      examples from fold-1 test chunk: [{ex}]")

    # --- build folds ---
    folds = []
    for f in range(k):
        test_memory  = list(parts[("memory", 5)][f]) + list(parts[("memory", 9)][f]) + list(parts[("memory", 13)][f])
        test_control = list(parts[("control", 5)][f]) + list(parts[("control", 9)][f]) + list(parts[("control", 13)][f])

        train_memory  = [x for i in range(k) if i != f for x in parts[("memory", 5)][i]] \
                      + [x for i in range(k) if i != f for x in parts[("memory", 9)][i]] \
                      + [x for i in range(k) if i != f for x in parts[("memory", 13)][i]]
        train_control = [x for i in range(k) if i != f for x in parts[("control", 5)][i]] \
                      + [x for i in range(k) if i != f for x in parts[("control", 9)][i]] \
                      + [x for i in range(k) if i != f for x in parts[("control", 13)][i]]

        folds.append({
            "train_memory":  train_memory,
            "test_memory":   test_memory,
            "train_control": train_control,
            "test_control":  test_control,
        })

    # --- per-fold debug summary ---
    if verbose:
        print("\n[Fold summaries]")
        for f, fold in enumerate(folds, 1):
            # count by load inside each set (memory/control)
            def _count_by_load(trials):
                a5, a9, a13 = split_trials_by_load(trials)
                return len(a5), len(a9), len(a13)
            tm5, tm9, tm13 = _count_by_load(fold["test_memory"])
            tc5, tc9, tc13 = _count_by_load(fold["test_control"])
            Trm5, Trm9, Trm13 = _count_by_load(fold["train_memory"])
            Trc5, Trc9, Trc13 = _count_by_load(fold["train_control"])

            print(f"  Fold {f}:")
            print(f"    TEST  mem: total={len(fold['test_memory'])}  by load: 05={tm5}, 09={tm9}, 13={tm13}")
            print(f"          ctrl: total={len(fold['test_control'])} by load: 05={tc5}, 09={tc9}, 13={tc13}")
            print(f"    TRAIN mem: total={len(fold['train_memory'])}  by load: 05={Trm5}, 09={Trm9}, 13={Trm13}")
            print(f"          ctrl: total={len(fold['train_control'])} by load: 05={Trc5}, 09={Trc9}, 13={Trc13}")

            if show_examples:
                tm_ex = ", ".join(_trial_tag(t) for t in fold["test_memory"][:show_examples])
                tc_ex = ", ".join(_trial_tag(t) for t in fold["test_control"][:show_examples])
                print(f"    examples TEST mem:  [{tm_ex}]")
                print(f"    examples TEST ctrl: [{tc_ex}]")

    # --- integrity checks (no leakage, full coverage, disjoint tests) ---
    if verbose:
        print("\n[Integrity checks]")
        # identity-based sets using id()
        all_mem_trials  = set(id(t) for t in buckets[("memory",5)] + buckets[("memory",9)] + buckets[("memory",13)])
        all_ctrl_trials = set(id(t) for t in buckets[("control",5)] + buckets[("control",9)] + buckets[("control",13)])

        # test coverage across folds
        mem_test_union  = set()
        ctrl_test_union = set()
        ok_disjoint = True
        seen_mem = set()
        seen_ctrl = set()

        for f, fold in enumerate(folds, 1):
            mem_ids  = [id(t) for t in fold["test_memory"]]
            ctrl_ids = [id(t) for t in fold["test_control"]]

            # disjointness of test sets across folds
            if mem_test_union.intersection(mem_ids) or ctrl_test_union.intersection(ctrl_ids):
                ok_disjoint = False
            mem_test_union.update(mem_ids)
            ctrl_test_union.update(ctrl_ids)

            # leakage: intersection between a fold's train and test
            leak_mem  = set(id(t) for t in fold["train_memory"]).intersection(mem_ids)
            leak_ctrl = set(id(t) for t in fold["train_control"]).intersection(ctrl_ids)
            print(f"  Fold {f} leakage mem={len(leak_mem)}  ctrl={len(leak_ctrl)}")

        print(f"  Test sets disjoint across folds? {'YES' if ok_disjoint else 'NO'}")
        print(f"  Memory test coverage {len(mem_test_union)}/{len(all_mem_trials)} "
              f"({len(mem_test_union)/max(1,len(all_mem_trials))*100:.1f}%)")
        print(f"  Control test coverage {len(ctrl_test_union)}/{len(all_ctrl_trials)} "
              f"({len(ctrl_test_union)/max(1,len(all_ctrl_trials))*100:.1f}%)")

    return folds

# %%
import random
from math import atanh, sqrt
from scipy.stats import norm, ttest_rel, wilcoxon

import matplotlib.pyplot as plt

K = 3
all_rows = []  # collect all trial-level results here
# best_shift_by_sub = {}  # best shift per subject
rows_trials = []
rows_subject = []
rows_folds   = []   # per-fold diagnostics  
bad_subjects_mem = []
bad_subjects_ctrl = []

for subj in SUBJECTS:
    if subj == 57:
        continue
    print(f"Processing subject {subj:02d}...")
    trials = load_all_trials(subj)                         # list of (eeg, pupil)
    trials_memory, trials_control = split_trials_by_condition(trials)

    random.shuffle(trials_memory)
    random.shuffle(trials_control)

    # --- build stratified folds (mem/ctrl × load) ---
    folds = stratified_kfold_trials(trials_memory, trials_control, k=K, show_examples=0)
    if not folds:
        print(f"Subject {subj:02d} skipped – not enough trials for {K}-fold stratification in all buckets.")
        continue

    # Use your precomputed best lag
    if subj not in best_shift_by_sub:
        print(f"Subject {subj:02d} missing best_shift_by_sub – skipped")
        continue
    best_shift = int(best_shift_by_sub[subj])

    win = slice(WIN_OFFSET1, -WIN_OFFSET2)

    fold_rs_mem  = []
    fold_rs_ctrl = []

    for fold_idx, fold in enumerate(folds, start=1):
        print(f"Fold {fold_idx}: mem_test={len(fold['test_memory'])}, ctrl_test={len(fold['test_control'])}, mem_train={len(fold['train_memory'])}, ctrl_train={len(fold['train_control'])}")

        train_trials = fold["train_memory"] + fold["train_control"]
        rng.shuffle(train_trials)  # keep training order random but reproducible

        # concat
        X_train, Y_train   = concat_trials(train_trials,            shift=best_shift, win=win)
        X_mem_test, Y_mem  = concat_trials(fold["test_memory"],     shift=best_shift, win=win)
        X_ctl_test, Y_ctl  = concat_trials(fold["test_control"],    shift=best_shift, win=win)

        # fit CCA once on the training set
        cca = CCA(n_components=1, max_iter=1000, scale=False, tol=1e-6)
        cca.fit(X_train, Y_train)

        # evaluate MEMORY
        u_m, v_m = cca.transform(X_mem_test, Y_mem)
        r_mem, p_mem = pearsonr(u_m[:, 0], v_m[:, 0])

        # evaluate CONTROL
        u_c, v_c = cca.transform(X_ctl_test, Y_ctl)
        r_ctrl, p_ctrl = pearsonr(u_c[:, 0], v_c[:, 0])

        n_mem  = u_m.shape[0]
        n_ctrl = u_c.shape[0]
        z_mem  = np.arctanh(r_mem)
        z_ctrl = np.arctanh(r_ctrl)
        se     = np.sqrt(1/(n_mem - 3) + 1/(n_ctrl - 3))
        z_stat = (z_mem - z_ctrl) / se
        p_one_sided = 1 - norm.cdf(z_stat)  # H1: r_mem > r_ctrl

        # rows per condition
        """
        rows_subject.append({
            "subject": subj, "fold": fold_idx, "condition": "memory",
            "lag_ms": best_shift * 10, "r": float(r_mem), "p-value": float(p_mem)
        })
        rows_subject.append({
            "subject": subj, "fold": fold_idx, "condition": "control",
            "lag_ms": best_shift * 10, "r": float(r_ctrl), "p-value": float(p_ctrl)
        })

        # per-fold per-subject test
        rows_subject.append({
            "subject": subj, "fold": fold_idx, "condition": "per-subject test",
            "lag_ms": best_shift * 10, "r_mem": float(r_mem), "r_ctrl": float(r_ctrl),
            "n_mem": int(n_mem), "n_ctrl": int(n_ctrl),
            "z_stat": float(z_stat), "p_one_sided": float(p_one_sided),
        })
    """
        fold_rs_mem.append(r_mem)
        fold_rs_ctrl.append(r_ctrl)

        rows_folds.append({
            "subject": subj, "fold": fold,
            "lag_ms": best_shift * 10,
            "r_memory_holdout": float(r_mem),
            "r_control_all":    float(r_ctrl)
        })
        # optional: flag “bad” per fold
        if p_ctrl > 0.05: bad_subjects_ctrl.append((subj, fold_idx))
        if p_mem  > 0.05: bad_subjects_mem.append((subj, fold_idx))

        # save weights per fold (keeps your existing helper)
        save_cca_weights(
            cca,
            subject_tag=f"sub-{subj:03d}",
            lag_ms=best_shift * 10,
            condition=f"mem_fold{fold_idx}",   # add fold tag
            eeg_ch_names=FRONTAL_MIDLINE,
            out_dir=Path("weights_k3_StratLoad")
        )
    
    mem_mean  = float(np.mean(fold_rs_mem))
    ctrl_mean = float(np.mean(fold_rs_ctrl))

    rows_subject.append({"subject": subj, "condition": "memory",  "r": mem_mean})
    rows_subject.append({"subject": subj, "condition": "control", "r": ctrl_mean})


df_subj = pd.DataFrame(rows_subject)
df_wide = df_subj.pivot(index="subject", columns="condition", values="r")

dfree = len(df_wide) - 1
t2, p2 = stats.ttest_rel(df_wide["memory"], df_wide["control"])
p_one = p2/2 if t2 > 0 else 1 - p2/2
print(f"Paired t-test: t={t2:.3f}, p_two={p2:.4f}, p_one(mem>ctl)={p_one:.4f}, df={dfree}")
# Out:
# Processing subject 33...
#
# [Bucket counts]
#   ('memory', 5): 35
#   ('memory', 9): 35
#   ('memory', 13): 36
#   ('control', 5): 18
#   ('control', 9): 18
#   ('control', 13): 18
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[12, 12, 11]  total=35
#   ('memory', 9): sizes=[12, 12, 11]  total=35
#   ('memory', 13): sizes=[12, 12, 12]  total=36
#   ('control', 5): sizes=[6, 6, 6]  total=18
#   ('control', 9): sizes=[6, 6, 6]  total=18
#   ('control', 13): sizes=[6, 6, 6]  total=18
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=36  by load: 05=12, 09=12, 13=12
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=70  by load: 05=23, 09=23, 13=24
#           ctrl: total=36 by load: 05=12, 09=12, 13=12
#   Fold 2:
#     TEST  mem: total=36  by load: 05=12, 09=12, 13=12
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=70  by load: 05=23, 09=23, 13=24
#           ctrl: total=36 by load: 05=12, 09=12, 13=12
#   Fold 3:
#     TEST  mem: total=34  by load: 05=11, 09=11, 13=12
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=72  by load: 05=24, 09=24, 13=24
#           ctrl: total=36 by load: 05=12, 09=12, 13=12
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 106/106 (100.0%)
#   Control test coverage 54/54 (100.0%)
# Fold 1: mem_test=36, ctrl_test=18, mem_train=70, ctrl_train=36
# saved weights for sub-033 (lag -50 ms)
# Fold 2: mem_test=36, ctrl_test=18, mem_train=70, ctrl_train=36
# saved weights for sub-033 (lag -50 ms)
# Fold 3: mem_test=34, ctrl_test=18, mem_train=72, ctrl_train=36
# saved weights for sub-033 (lag -50 ms)
# Processing subject 34...
#
# [Bucket counts]
#   ('memory', 5): 35
#   ('memory', 9): 30
#   ('memory', 13): 32
#   ('control', 5): 15
#   ('control', 9): 14
#   ('control', 13): 16
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[12, 12, 11]  total=35
#   ('memory', 9): sizes=[10, 10, 10]  total=30
#   ('memory', 13): sizes=[11, 11, 10]  total=32
#   ('control', 5): sizes=[5, 5, 5]  total=15
#   ('control', 9): sizes=[5, 5, 4]  total=14
#   ('control', 13): sizes=[6, 5, 5]  total=16
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=33  by load: 05=12, 09=10, 13=11
#           ctrl: total=16 by load: 05=5, 09=5, 13=6
#     TRAIN mem: total=64  by load: 05=23, 09=20, 13=21
#           ctrl: total=29 by load: 05=10, 09=9, 13=10
#   Fold 2:
#     TEST  mem: total=33  by load: 05=12, 09=10, 13=11
#           ctrl: total=15 by load: 05=5, 09=5, 13=5
#     TRAIN mem: total=64  by load: 05=23, 09=20, 13=21
#           ctrl: total=30 by load: 05=10, 09=9, 13=11
#   Fold 3:
#     TEST  mem: total=31  by load: 05=11, 09=10, 13=10
#           ctrl: total=14 by load: 05=5, 09=4, 13=5
#     TRAIN mem: total=66  by load: 05=24, 09=20, 13=22
#           ctrl: total=31 by load: 05=10, 09=10, 13=11
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 97/97 (100.0%)
#   Control test coverage 45/45 (100.0%)
# Fold 1: mem_test=33, ctrl_test=16, mem_train=64, ctrl_train=29
# saved weights for sub-034 (lag +320 ms)
# Fold 2: mem_test=33, ctrl_test=15, mem_train=64, ctrl_train=30
# saved weights for sub-034 (lag +320 ms)
# Fold 3: mem_test=31, ctrl_test=14, mem_train=66, ctrl_train=31
# saved weights for sub-034 (lag +320 ms)
# Processing subject 35...
#
# [Bucket counts]
#   ('memory', 5): 11
#   ('memory', 9): 4
#   ('memory', 13): 1
#   ('control', 5): 5
#   ('control', 9): 5
#   ('control', 13): 5
# [WARN] Not enough trials for k=3 in buckets: [('memory', 13)]. Returning [].
# Subject 35 skipped – not enough trials for 3-fold stratification in all buckets.
# Processing subject 36...
#
# [Bucket counts]
#   ('memory', 5): 14
#   ('memory', 9): 13
#   ('memory', 13): 16
#   ('control', 5): 10
#   ('control', 9): 8
#   ('control', 13): 8
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[5, 5, 4]  total=14
#   ('memory', 9): sizes=[5, 4, 4]  total=13
#   ('memory', 13): sizes=[6, 5, 5]  total=16
#   ('control', 5): sizes=[4, 3, 3]  total=10
#   ('control', 9): sizes=[3, 3, 2]  total=8
#   ('control', 13): sizes=[3, 3, 2]  total=8
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=16  by load: 05=5, 09=5, 13=6
#           ctrl: total=10 by load: 05=4, 09=3, 13=3
#     TRAIN mem: total=27  by load: 05=9, 09=8, 13=10
#           ctrl: total=16 by load: 05=6, 09=5, 13=5
#   Fold 2:
#     TEST  mem: total=14  by load: 05=5, 09=4, 13=5
#           ctrl: total=9 by load: 05=3, 09=3, 13=3
#     TRAIN mem: total=29  by load: 05=9, 09=9, 13=11
#           ctrl: total=17 by load: 05=7, 09=5, 13=5
#   Fold 3:
#     TEST  mem: total=13  by load: 05=4, 09=4, 13=5
#           ctrl: total=7 by load: 05=3, 09=2, 13=2
#     TRAIN mem: total=30  by load: 05=10, 09=9, 13=11
#           ctrl: total=19 by load: 05=7, 09=6, 13=6
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 43/43 (100.0%)
#   Control test coverage 26/26 (100.0%)
# Fold 1: mem_test=16, ctrl_test=10, mem_train=27, ctrl_train=16
# saved weights for sub-036 (lag -590 ms)
# Fold 2: mem_test=14, ctrl_test=9, mem_train=29, ctrl_train=17
# saved weights for sub-036 (lag -590 ms)
# Fold 3: mem_test=13, ctrl_test=7, mem_train=30, ctrl_train=19
# saved weights for sub-036 (lag -590 ms)
# Processing subject 38...
#
# [Bucket counts]
#   ('memory', 5): 17
#   ('memory', 9): 21
#   ('memory', 13): 21
#   ('control', 5): 12
#   ('control', 9): 11
#   ('control', 13): 9
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[6, 6, 5]  total=17
#   ('memory', 9): sizes=[7, 7, 7]  total=21
#   ('memory', 13): sizes=[7, 7, 7]  total=21
#   ('control', 5): sizes=[4, 4, 4]  total=12
#   ('control', 9): sizes=[4, 4, 3]  total=11
#   ('control', 13): sizes=[3, 3, 3]  total=9
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=20  by load: 05=6, 09=7, 13=7
#           ctrl: total=11 by load: 05=4, 09=4, 13=3
#     TRAIN mem: total=39  by load: 05=11, 09=14, 13=14
#           ctrl: total=21 by load: 05=8, 09=7, 13=6
#   Fold 2:
#     TEST  mem: total=20  by load: 05=6, 09=7, 13=7
#           ctrl: total=11 by load: 05=4, 09=4, 13=3
#     TRAIN mem: total=39  by load: 05=11, 09=14, 13=14
#           ctrl: total=21 by load: 05=8, 09=7, 13=6
#   Fold 3:
#     TEST  mem: total=19  by load: 05=5, 09=7, 13=7
#           ctrl: total=10 by load: 05=4, 09=3, 13=3
#     TRAIN mem: total=40  by load: 05=12, 09=14, 13=14
#           ctrl: total=22 by load: 05=8, 09=8, 13=6
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 59/59 (100.0%)
#   Control test coverage 32/32 (100.0%)
# Fold 1: mem_test=20, ctrl_test=11, mem_train=39, ctrl_train=21
# saved weights for sub-038 (lag -10 ms)
# Fold 2: mem_test=20, ctrl_test=11, mem_train=39, ctrl_train=21
# saved weights for sub-038 (lag -10 ms)
# Fold 3: mem_test=19, ctrl_test=10, mem_train=40, ctrl_train=22
# saved weights for sub-038 (lag -10 ms)
# Processing subject 39...
#
# [Bucket counts]
#   ('memory', 5): 30
#   ('memory', 9): 23
#   ('memory', 13): 22
#   ('control', 5): 17
#   ('control', 9): 16
#   ('control', 13): 17
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[10, 10, 10]  total=30
#   ('memory', 9): sizes=[8, 8, 7]  total=23
#   ('memory', 13): sizes=[8, 7, 7]  total=22
#   ('control', 5): sizes=[6, 6, 5]  total=17
#   ('control', 9): sizes=[6, 5, 5]  total=16
#   ('control', 13): sizes=[6, 6, 5]  total=17
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=26  by load: 05=10, 09=8, 13=8
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=49  by load: 05=20, 09=15, 13=14
#           ctrl: total=32 by load: 05=11, 09=10, 13=11
#   Fold 2:
#     TEST  mem: total=25  by load: 05=10, 09=8, 13=7
#           ctrl: total=17 by load: 05=6, 09=5, 13=6
#     TRAIN mem: total=50  by load: 05=20, 09=15, 13=15
#           ctrl: total=33 by load: 05=11, 09=11, 13=11
#   Fold 3:
#     TEST  mem: total=24  by load: 05=10, 09=7, 13=7
#           ctrl: total=15 by load: 05=5, 09=5, 13=5
#     TRAIN mem: total=51  by load: 05=20, 09=16, 13=15
#           ctrl: total=35 by load: 05=12, 09=11, 13=12
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 75/75 (100.0%)
#   Control test coverage 50/50 (100.0%)
# Fold 1: mem_test=26, ctrl_test=18, mem_train=49, ctrl_train=32
# saved weights for sub-039 (lag +20 ms)
# Fold 2: mem_test=25, ctrl_test=17, mem_train=50, ctrl_train=33
# saved weights for sub-039 (lag +20 ms)
# Fold 3: mem_test=24, ctrl_test=15, mem_train=51, ctrl_train=35
# saved weights for sub-039 (lag +20 ms)
# Processing subject 40...
#
# [Bucket counts]
#   ('memory', 5): 28
#   ('memory', 9): 23
#   ('memory', 13): 23
#   ('control', 5): 18
#   ('control', 9): 16
#   ('control', 13): 18
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[10, 9, 9]  total=28
#   ('memory', 9): sizes=[8, 8, 7]  total=23
#   ('memory', 13): sizes=[8, 8, 7]  total=23
#   ('control', 5): sizes=[6, 6, 6]  total=18
#   ('control', 9): sizes=[6, 5, 5]  total=16
#   ('control', 13): sizes=[6, 6, 6]  total=18
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=26  by load: 05=10, 09=8, 13=8
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=48  by load: 05=18, 09=15, 13=15
#           ctrl: total=34 by load: 05=12, 09=10, 13=12
#   Fold 2:
#     TEST  mem: total=25  by load: 05=9, 09=8, 13=8
#           ctrl: total=17 by load: 05=6, 09=5, 13=6
#     TRAIN mem: total=49  by load: 05=19, 09=15, 13=15
#           ctrl: total=35 by load: 05=12, 09=11, 13=12
#   Fold 3:
#     TEST  mem: total=23  by load: 05=9, 09=7, 13=7
#           ctrl: total=17 by load: 05=6, 09=5, 13=6
#     TRAIN mem: total=51  by load: 05=19, 09=16, 13=16
#           ctrl: total=35 by load: 05=12, 09=11, 13=12
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 74/74 (100.0%)
#   Control test coverage 52/52 (100.0%)
# Fold 1: mem_test=26, ctrl_test=18, mem_train=48, ctrl_train=34
# saved weights for sub-040 (lag +1000 ms)
# Fold 2: mem_test=25, ctrl_test=17, mem_train=49, ctrl_train=35
# saved weights for sub-040 (lag +1000 ms)
# Fold 3: mem_test=23, ctrl_test=17, mem_train=51, ctrl_train=35
# saved weights for sub-040 (lag +1000 ms)
# Processing subject 41...
#
# [Bucket counts]
#   ('memory', 5): 36
#   ('memory', 9): 36
#   ('memory', 13): 36
#   ('control', 5): 18
#   ('control', 9): 18
#   ('control', 13): 17
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[12, 12, 12]  total=36
#   ('memory', 9): sizes=[12, 12, 12]  total=36
#   ('memory', 13): sizes=[12, 12, 12]  total=36
#   ('control', 5): sizes=[6, 6, 6]  total=18
#   ('control', 9): sizes=[6, 6, 6]  total=18
#   ('control', 13): sizes=[6, 6, 5]  total=17
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=36  by load: 05=12, 09=12, 13=12
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=72  by load: 05=24, 09=24, 13=24
#           ctrl: total=35 by load: 05=12, 09=12, 13=11
#   Fold 2:
#     TEST  mem: total=36  by load: 05=12, 09=12, 13=12
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=72  by load: 05=24, 09=24, 13=24
#           ctrl: total=35 by load: 05=12, 09=12, 13=11
#   Fold 3:
#     TEST  mem: total=36  by load: 05=12, 09=12, 13=12
#           ctrl: total=17 by load: 05=6, 09=6, 13=5
#     TRAIN mem: total=72  by load: 05=24, 09=24, 13=24
#           ctrl: total=36 by load: 05=12, 09=12, 13=12
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 108/108 (100.0%)
#   Control test coverage 53/53 (100.0%)
# Fold 1: mem_test=36, ctrl_test=18, mem_train=72, ctrl_train=35
# saved weights for sub-041 (lag -100 ms)
# Fold 2: mem_test=36, ctrl_test=18, mem_train=72, ctrl_train=35
# saved weights for sub-041 (lag -100 ms)
# Fold 3: mem_test=36, ctrl_test=17, mem_train=72, ctrl_train=36
# saved weights for sub-041 (lag -100 ms)
# Processing subject 42...
#
# [Bucket counts]
#   ('memory', 5): 34
#   ('memory', 9): 34
#   ('memory', 13): 34
#   ('control', 5): 16
#   ('control', 9): 16
#   ('control', 13): 15
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[12, 11, 11]  total=34
#   ('memory', 9): sizes=[12, 11, 11]  total=34
#   ('memory', 13): sizes=[12, 11, 11]  total=34
#   ('control', 5): sizes=[6, 5, 5]  total=16
#   ('control', 9): sizes=[6, 5, 5]  total=16
#   ('control', 13): sizes=[5, 5, 5]  total=15
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=36  by load: 05=12, 09=12, 13=12
#           ctrl: total=17 by load: 05=6, 09=6, 13=5
#     TRAIN mem: total=66  by load: 05=22, 09=22, 13=22
#           ctrl: total=30 by load: 05=10, 09=10, 13=10
#   Fold 2:
#     TEST  mem: total=33  by load: 05=11, 09=11, 13=11
#           ctrl: total=15 by load: 05=5, 09=5, 13=5
#     TRAIN mem: total=69  by load: 05=23, 09=23, 13=23
#           ctrl: total=32 by load: 05=11, 09=11, 13=10
#   Fold 3:
#     TEST  mem: total=33  by load: 05=11, 09=11, 13=11
#           ctrl: total=15 by load: 05=5, 09=5, 13=5
#     TRAIN mem: total=69  by load: 05=23, 09=23, 13=23
#           ctrl: total=32 by load: 05=11, 09=11, 13=10
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 102/102 (100.0%)
#   Control test coverage 47/47 (100.0%)
# Fold 1: mem_test=36, ctrl_test=17, mem_train=66, ctrl_train=30
# saved weights for sub-042 (lag -800 ms)
# Fold 2: mem_test=33, ctrl_test=15, mem_train=69, ctrl_train=32
# saved weights for sub-042 (lag -800 ms)
# Fold 3: mem_test=33, ctrl_test=15, mem_train=69, ctrl_train=32
# saved weights for sub-042 (lag -800 ms)
# Processing subject 43...
#
# [Bucket counts]
#   ('memory', 5): 31
#   ('memory', 9): 32
#   ('memory', 13): 30
#   ('control', 5): 17
#   ('control', 9): 14
#   ('control', 13): 18
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[11, 10, 10]  total=31
#   ('memory', 9): sizes=[11, 11, 10]  total=32
#   ('memory', 13): sizes=[10, 10, 10]  total=30
#   ('control', 5): sizes=[6, 6, 5]  total=17
#   ('control', 9): sizes=[5, 5, 4]  total=14
#   ('control', 13): sizes=[6, 6, 6]  total=18
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=32  by load: 05=11, 09=11, 13=10
#           ctrl: total=17 by load: 05=6, 09=5, 13=6
#     TRAIN mem: total=61  by load: 05=20, 09=21, 13=20
#           ctrl: total=32 by load: 05=11, 09=9, 13=12
#   Fold 2:
#     TEST  mem: total=31  by load: 05=10, 09=11, 13=10
#           ctrl: total=17 by load: 05=6, 09=5, 13=6
#     TRAIN mem: total=62  by load: 05=21, 09=21, 13=20
#           ctrl: total=32 by load: 05=11, 09=9, 13=12
#   Fold 3:
#     TEST  mem: total=30  by load: 05=10, 09=10, 13=10
#           ctrl: total=15 by load: 05=5, 09=4, 13=6
#     TRAIN mem: total=63  by load: 05=21, 09=22, 13=20
#           ctrl: total=34 by load: 05=12, 09=10, 13=12
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 93/93 (100.0%)
#   Control test coverage 49/49 (100.0%)
# Fold 1: mem_test=32, ctrl_test=17, mem_train=61, ctrl_train=32
# saved weights for sub-043 (lag +700 ms)
# Fold 2: mem_test=31, ctrl_test=17, mem_train=62, ctrl_train=32
# saved weights for sub-043 (lag +700 ms)
# Fold 3: mem_test=30, ctrl_test=15, mem_train=63, ctrl_train=34
# saved weights for sub-043 (lag +700 ms)
# Processing subject 44...
#
# [Bucket counts]
#   ('memory', 5): 33
#   ('memory', 9): 33
#   ('memory', 13): 32
#   ('control', 5): 16
#   ('control', 9): 18
#   ('control', 13): 18
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[11, 11, 11]  total=33
#   ('memory', 9): sizes=[11, 11, 11]  total=33
#   ('memory', 13): sizes=[11, 11, 10]  total=32
#   ('control', 5): sizes=[6, 5, 5]  total=16
#   ('control', 9): sizes=[6, 6, 6]  total=18
#   ('control', 13): sizes=[6, 6, 6]  total=18
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=33  by load: 05=11, 09=11, 13=11
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=65  by load: 05=22, 09=22, 13=21
#           ctrl: total=34 by load: 05=10, 09=12, 13=12
#   Fold 2:
#     TEST  mem: total=33  by load: 05=11, 09=11, 13=11
#           ctrl: total=17 by load: 05=5, 09=6, 13=6
#     TRAIN mem: total=65  by load: 05=22, 09=22, 13=21
#           ctrl: total=35 by load: 05=11, 09=12, 13=12
#   Fold 3:
#     TEST  mem: total=32  by load: 05=11, 09=11, 13=10
#           ctrl: total=17 by load: 05=5, 09=6, 13=6
#     TRAIN mem: total=66  by load: 05=22, 09=22, 13=22
#           ctrl: total=35 by load: 05=11, 09=12, 13=12
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 98/98 (100.0%)
#   Control test coverage 52/52 (100.0%)
# Fold 1: mem_test=33, ctrl_test=18, mem_train=65, ctrl_train=34
# saved weights for sub-044 (lag -100 ms)
# Fold 2: mem_test=33, ctrl_test=17, mem_train=65, ctrl_train=35
# saved weights for sub-044 (lag -100 ms)
# Fold 3: mem_test=32, ctrl_test=17, mem_train=66, ctrl_train=35
# saved weights for sub-044 (lag -100 ms)
# Processing subject 45...
#
# [Bucket counts]
#   ('memory', 5): 18
#   ('memory', 9): 22
#   ('memory', 13): 24
#   ('control', 5): 14
#   ('control', 9): 14
#   ('control', 13): 14
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[6, 6, 6]  total=18
#   ('memory', 9): sizes=[8, 7, 7]  total=22
#   ('memory', 13): sizes=[8, 8, 8]  total=24
#   ('control', 5): sizes=[5, 5, 4]  total=14
#   ('control', 9): sizes=[5, 5, 4]  total=14
#   ('control', 13): sizes=[5, 5, 4]  total=14
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=22  by load: 05=6, 09=8, 13=8
#           ctrl: total=15 by load: 05=5, 09=5, 13=5
#     TRAIN mem: total=42  by load: 05=12, 09=14, 13=16
#           ctrl: total=27 by load: 05=9, 09=9, 13=9
#   Fold 2:
#     TEST  mem: total=21  by load: 05=6, 09=7, 13=8
#           ctrl: total=15 by load: 05=5, 09=5, 13=5
#     TRAIN mem: total=43  by load: 05=12, 09=15, 13=16
#           ctrl: total=27 by load: 05=9, 09=9, 13=9
#   Fold 3:
#     TEST  mem: total=21  by load: 05=6, 09=7, 13=8
#           ctrl: total=12 by load: 05=4, 09=4, 13=4
#     TRAIN mem: total=43  by load: 05=12, 09=15, 13=16
#           ctrl: total=30 by load: 05=10, 09=10, 13=10
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 64/64 (100.0%)
#   Control test coverage 42/42 (100.0%)
# Fold 1: mem_test=22, ctrl_test=15, mem_train=42, ctrl_train=27
# saved weights for sub-045 (lag +420 ms)
# Fold 2: mem_test=21, ctrl_test=15, mem_train=43, ctrl_train=27
# saved weights for sub-045 (lag +420 ms)
# Fold 3: mem_test=21, ctrl_test=12, mem_train=43, ctrl_train=30
# saved weights for sub-045 (lag +420 ms)
# Processing subject 46...
#
# [Bucket counts]
#   ('memory', 5): 6
#   ('memory', 9): 0
#   ('memory', 13): 2
#   ('control', 5): 1
#   ('control', 9): 3
#   ('control', 13): 2
# [WARN] Not enough trials for k=3 in buckets: [('memory', 9), ('memory', 13), ('control', 5), ('control', 13)]. Returning [].
# Subject 46 skipped – not enough trials for 3-fold stratification in all buckets.
# Processing subject 47...
#
# [Bucket counts]
#   ('memory', 5): 15
#   ('memory', 9): 13
#   ('memory', 13): 13
#   ('control', 5): 11
#   ('control', 9): 12
#   ('control', 13): 10
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[5, 5, 5]  total=15
#   ('memory', 9): sizes=[5, 4, 4]  total=13
#   ('memory', 13): sizes=[5, 4, 4]  total=13
#   ('control', 5): sizes=[4, 4, 3]  total=11
#   ('control', 9): sizes=[4, 4, 4]  total=12
#   ('control', 13): sizes=[4, 3, 3]  total=10
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=15  by load: 05=5, 09=5, 13=5
#           ctrl: total=12 by load: 05=4, 09=4, 13=4
#     TRAIN mem: total=26  by load: 05=10, 09=8, 13=8
#           ctrl: total=21 by load: 05=7, 09=8, 13=6
#   Fold 2:
#     TEST  mem: total=13  by load: 05=5, 09=4, 13=4
#           ctrl: total=11 by load: 05=4, 09=4, 13=3
#     TRAIN mem: total=28  by load: 05=10, 09=9, 13=9
#           ctrl: total=22 by load: 05=7, 09=8, 13=7
#   Fold 3:
#     TEST  mem: total=13  by load: 05=5, 09=4, 13=4
#           ctrl: total=10 by load: 05=3, 09=4, 13=3
#     TRAIN mem: total=28  by load: 05=10, 09=9, 13=9
#           ctrl: total=23 by load: 05=8, 09=8, 13=7
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 41/41 (100.0%)
#   Control test coverage 33/33 (100.0%)
# Fold 1: mem_test=15, ctrl_test=12, mem_train=26, ctrl_train=21
# saved weights for sub-047 (lag +1000 ms)
# Fold 2: mem_test=13, ctrl_test=11, mem_train=28, ctrl_train=22
# saved weights for sub-047 (lag +1000 ms)
# Fold 3: mem_test=13, ctrl_test=10, mem_train=28, ctrl_train=23
# saved weights for sub-047 (lag +1000 ms)
# Processing subject 48...
#
# [Bucket counts]
#   ('memory', 5): 23
#   ('memory', 9): 13
#   ('memory', 13): 14
#   ('control', 5): 12
#   ('control', 9): 16
#   ('control', 13): 15
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[8, 8, 7]  total=23
#   ('memory', 9): sizes=[5, 4, 4]  total=13
#   ('memory', 13): sizes=[5, 5, 4]  total=14
#   ('control', 5): sizes=[4, 4, 4]  total=12
#   ('control', 9): sizes=[6, 5, 5]  total=16
#   ('control', 13): sizes=[5, 5, 5]  total=15
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=18  by load: 05=8, 09=5, 13=5
#           ctrl: total=15 by load: 05=4, 09=6, 13=5
#     TRAIN mem: total=32  by load: 05=15, 09=8, 13=9
#           ctrl: total=28 by load: 05=8, 09=10, 13=10
#   Fold 2:
#     TEST  mem: total=17  by load: 05=8, 09=4, 13=5
#           ctrl: total=14 by load: 05=4, 09=5, 13=5
#     TRAIN mem: total=33  by load: 05=15, 09=9, 13=9
#           ctrl: total=29 by load: 05=8, 09=11, 13=10
#   Fold 3:
#     TEST  mem: total=15  by load: 05=7, 09=4, 13=4
#           ctrl: total=14 by load: 05=4, 09=5, 13=5
#     TRAIN mem: total=35  by load: 05=16, 09=9, 13=10
#           ctrl: total=29 by load: 05=8, 09=11, 13=10
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 50/50 (100.0%)
#   Control test coverage 43/43 (100.0%)
# Fold 1: mem_test=18, ctrl_test=15, mem_train=32, ctrl_train=28
# saved weights for sub-048 (lag -630 ms)
# Fold 2: mem_test=17, ctrl_test=14, mem_train=33, ctrl_train=29
# saved weights for sub-048 (lag -630 ms)
# Fold 3: mem_test=15, ctrl_test=14, mem_train=35, ctrl_train=29
# saved weights for sub-048 (lag -630 ms)
# Processing subject 49...
#
# [Bucket counts]
#   ('memory', 5): 25
#   ('memory', 9): 22
#   ('memory', 13): 19
#   ('control', 5): 13
#   ('control', 9): 12
#   ('control', 13): 15
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[9, 8, 8]  total=25
#   ('memory', 9): sizes=[8, 7, 7]  total=22
#   ('memory', 13): sizes=[7, 6, 6]  total=19
#   ('control', 5): sizes=[5, 4, 4]  total=13
#   ('control', 9): sizes=[4, 4, 4]  total=12
#   ('control', 13): sizes=[5, 5, 5]  total=15
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=24  by load: 05=9, 09=8, 13=7
#           ctrl: total=14 by load: 05=5, 09=4, 13=5
#     TRAIN mem: total=42  by load: 05=16, 09=14, 13=12
#           ctrl: total=26 by load: 05=8, 09=8, 13=10
#   Fold 2:
#     TEST  mem: total=21  by load: 05=8, 09=7, 13=6
#           ctrl: total=13 by load: 05=4, 09=4, 13=5
#     TRAIN mem: total=45  by load: 05=17, 09=15, 13=13
#           ctrl: total=27 by load: 05=9, 09=8, 13=10
#   Fold 3:
#     TEST  mem: total=21  by load: 05=8, 09=7, 13=6
#           ctrl: total=13 by load: 05=4, 09=4, 13=5
#     TRAIN mem: total=45  by load: 05=17, 09=15, 13=13
#           ctrl: total=27 by load: 05=9, 09=8, 13=10
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 66/66 (100.0%)
#   Control test coverage 40/40 (100.0%)
# Fold 1: mem_test=24, ctrl_test=14, mem_train=42, ctrl_train=26
# saved weights for sub-049 (lag +460 ms)
# Fold 2: mem_test=21, ctrl_test=13, mem_train=45, ctrl_train=27
# saved weights for sub-049 (lag +460 ms)
# Fold 3: mem_test=21, ctrl_test=13, mem_train=45, ctrl_train=27
# saved weights for sub-049 (lag +460 ms)
# Processing subject 50...
#
# [Bucket counts]
#   ('memory', 5): 36
#   ('memory', 9): 36
#   ('memory', 13): 36
#   ('control', 5): 17
#   ('control', 9): 18
#   ('control', 13): 18
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[12, 12, 12]  total=36
#   ('memory', 9): sizes=[12, 12, 12]  total=36
#   ('memory', 13): sizes=[12, 12, 12]  total=36
#   ('control', 5): sizes=[6, 6, 5]  total=17
#   ('control', 9): sizes=[6, 6, 6]  total=18
#   ('control', 13): sizes=[6, 6, 6]  total=18
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=36  by load: 05=12, 09=12, 13=12
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=72  by load: 05=24, 09=24, 13=24
#           ctrl: total=35 by load: 05=11, 09=12, 13=12
#   Fold 2:
#     TEST  mem: total=36  by load: 05=12, 09=12, 13=12
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=72  by load: 05=24, 09=24, 13=24
#           ctrl: total=35 by load: 05=11, 09=12, 13=12
#   Fold 3:
#     TEST  mem: total=36  by load: 05=12, 09=12, 13=12
#           ctrl: total=17 by load: 05=5, 09=6, 13=6
#     TRAIN mem: total=72  by load: 05=24, 09=24, 13=24
#           ctrl: total=36 by load: 05=12, 09=12, 13=12
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 108/108 (100.0%)
#   Control test coverage 53/53 (100.0%)
# Fold 1: mem_test=36, ctrl_test=18, mem_train=72, ctrl_train=35
# saved weights for sub-050 (lag +910 ms)
# Fold 2: mem_test=36, ctrl_test=18, mem_train=72, ctrl_train=35
# saved weights for sub-050 (lag +910 ms)
# Fold 3: mem_test=36, ctrl_test=17, mem_train=72, ctrl_train=36
# saved weights for sub-050 (lag +910 ms)
# Processing subject 51...
#
# [Bucket counts]
#   ('memory', 5): 14
#   ('memory', 9): 14
#   ('memory', 13): 16
#   ('control', 5): 8
#   ('control', 9): 5
#   ('control', 13): 9
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[5, 5, 4]  total=14
#   ('memory', 9): sizes=[5, 5, 4]  total=14
#   ('memory', 13): sizes=[6, 5, 5]  total=16
#   ('control', 5): sizes=[3, 3, 2]  total=8
#   ('control', 9): sizes=[2, 2, 1]  total=5
#   ('control', 13): sizes=[3, 3, 3]  total=9
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=16  by load: 05=5, 09=5, 13=6
#           ctrl: total=8 by load: 05=3, 09=2, 13=3
#     TRAIN mem: total=28  by load: 05=9, 09=9, 13=10
#           ctrl: total=14 by load: 05=5, 09=3, 13=6
#   Fold 2:
#     TEST  mem: total=15  by load: 05=5, 09=5, 13=5
#           ctrl: total=8 by load: 05=3, 09=2, 13=3
#     TRAIN mem: total=29  by load: 05=9, 09=9, 13=11
#           ctrl: total=14 by load: 05=5, 09=3, 13=6
#   Fold 3:
#     TEST  mem: total=13  by load: 05=4, 09=4, 13=5
#           ctrl: total=6 by load: 05=2, 09=1, 13=3
#     TRAIN mem: total=31  by load: 05=10, 09=10, 13=11
#           ctrl: total=16 by load: 05=6, 09=4, 13=6
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 44/44 (100.0%)
#   Control test coverage 22/22 (100.0%)
# Fold 1: mem_test=16, ctrl_test=8, mem_train=28, ctrl_train=14
# saved weights for sub-051 (lag +1000 ms)
# Fold 2: mem_test=15, ctrl_test=8, mem_train=29, ctrl_train=14
# saved weights for sub-051 (lag +1000 ms)
# Fold 3: mem_test=13, ctrl_test=6, mem_train=31, ctrl_train=16
# saved weights for sub-051 (lag +1000 ms)
# Processing subject 52...
#
# [Bucket counts]
#   ('memory', 5): 12
#   ('memory', 9): 11
#   ('memory', 13): 17
#   ('control', 5): 10
#   ('control', 9): 9
#   ('control', 13): 9
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[4, 4, 4]  total=12
#   ('memory', 9): sizes=[4, 4, 3]  total=11
#   ('memory', 13): sizes=[6, 6, 5]  total=17
#   ('control', 5): sizes=[4, 3, 3]  total=10
#   ('control', 9): sizes=[3, 3, 3]  total=9
#   ('control', 13): sizes=[3, 3, 3]  total=9
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=14  by load: 05=4, 09=4, 13=6
#           ctrl: total=10 by load: 05=4, 09=3, 13=3
#     TRAIN mem: total=26  by load: 05=8, 09=7, 13=11
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#   Fold 2:
#     TEST  mem: total=14  by load: 05=4, 09=4, 13=6
#           ctrl: total=9 by load: 05=3, 09=3, 13=3
#     TRAIN mem: total=26  by load: 05=8, 09=7, 13=11
#           ctrl: total=19 by load: 05=7, 09=6, 13=6
#   Fold 3:
#     TEST  mem: total=12  by load: 05=4, 09=3, 13=5
#           ctrl: total=9 by load: 05=3, 09=3, 13=3
#     TRAIN mem: total=28  by load: 05=8, 09=8, 13=12
#           ctrl: total=19 by load: 05=7, 09=6, 13=6
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 40/40 (100.0%)
#   Control test coverage 28/28 (100.0%)
# Fold 1: mem_test=14, ctrl_test=10, mem_train=26, ctrl_train=18
# saved weights for sub-052 (lag +810 ms)
# Fold 2: mem_test=14, ctrl_test=9, mem_train=26, ctrl_train=19
# saved weights for sub-052 (lag +810 ms)
# Fold 3: mem_test=12, ctrl_test=9, mem_train=28, ctrl_train=19
# saved weights for sub-052 (lag +810 ms)
# Processing subject 54...
#
# [Bucket counts]
#   ('memory', 5): 29
#   ('memory', 9): 29
#   ('memory', 13): 33
#   ('control', 5): 16
#   ('control', 9): 17
#   ('control', 13): 17
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[10, 10, 9]  total=29
#   ('memory', 9): sizes=[10, 10, 9]  total=29
#   ('memory', 13): sizes=[11, 11, 11]  total=33
#   ('control', 5): sizes=[6, 5, 5]  total=16
#   ('control', 9): sizes=[6, 6, 5]  total=17
#   ('control', 13): sizes=[6, 6, 5]  total=17
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=31  by load: 05=10, 09=10, 13=11
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=60  by load: 05=19, 09=19, 13=22
#           ctrl: total=32 by load: 05=10, 09=11, 13=11
#   Fold 2:
#     TEST  mem: total=31  by load: 05=10, 09=10, 13=11
#           ctrl: total=17 by load: 05=5, 09=6, 13=6
#     TRAIN mem: total=60  by load: 05=19, 09=19, 13=22
#           ctrl: total=33 by load: 05=11, 09=11, 13=11
#   Fold 3:
#     TEST  mem: total=29  by load: 05=9, 09=9, 13=11
#           ctrl: total=15 by load: 05=5, 09=5, 13=5
#     TRAIN mem: total=62  by load: 05=20, 09=20, 13=22
#           ctrl: total=35 by load: 05=11, 09=12, 13=12
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 91/91 (100.0%)
#   Control test coverage 50/50 (100.0%)
# Fold 1: mem_test=31, ctrl_test=18, mem_train=60, ctrl_train=32
# saved weights for sub-054 (lag +630 ms)
# Fold 2: mem_test=31, ctrl_test=17, mem_train=60, ctrl_train=33
# saved weights for sub-054 (lag +630 ms)
# Fold 3: mem_test=29, ctrl_test=15, mem_train=62, ctrl_train=35
# saved weights for sub-054 (lag +630 ms)
# Processing subject 55...
#
# [Bucket counts]
#   ('memory', 5): 29
#   ('memory', 9): 34
#   ('memory', 13): 27
#   ('control', 5): 15
#   ('control', 9): 17
#   ('control', 13): 14
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[10, 10, 9]  total=29
#   ('memory', 9): sizes=[12, 11, 11]  total=34
#   ('memory', 13): sizes=[9, 9, 9]  total=27
#   ('control', 5): sizes=[5, 5, 5]  total=15
#   ('control', 9): sizes=[6, 6, 5]  total=17
#   ('control', 13): sizes=[5, 5, 4]  total=14
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=31  by load: 05=10, 09=12, 13=9
#           ctrl: total=16 by load: 05=5, 09=6, 13=5
#     TRAIN mem: total=59  by load: 05=19, 09=22, 13=18
#           ctrl: total=30 by load: 05=10, 09=11, 13=9
#   Fold 2:
#     TEST  mem: total=30  by load: 05=10, 09=11, 13=9
#           ctrl: total=16 by load: 05=5, 09=6, 13=5
#     TRAIN mem: total=60  by load: 05=19, 09=23, 13=18
#           ctrl: total=30 by load: 05=10, 09=11, 13=9
#   Fold 3:
#     TEST  mem: total=29  by load: 05=9, 09=11, 13=9
#           ctrl: total=14 by load: 05=5, 09=5, 13=4
#     TRAIN mem: total=61  by load: 05=20, 09=23, 13=18
#           ctrl: total=32 by load: 05=10, 09=12, 13=10
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 90/90 (100.0%)
#   Control test coverage 46/46 (100.0%)
# Fold 1: mem_test=31, ctrl_test=16, mem_train=59, ctrl_train=30
# saved weights for sub-055 (lag -380 ms)
# Fold 2: mem_test=30, ctrl_test=16, mem_train=60, ctrl_train=30
# saved weights for sub-055 (lag -380 ms)
# Fold 3: mem_test=29, ctrl_test=14, mem_train=61, ctrl_train=32
# saved weights for sub-055 (lag -380 ms)
# Processing subject 56...
#
# [Bucket counts]
#   ('memory', 5): 29
#   ('memory', 9): 25
#   ('memory', 13): 29
#   ('control', 5): 14
#   ('control', 9): 16
#   ('control', 13): 15
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[10, 10, 9]  total=29
#   ('memory', 9): sizes=[9, 8, 8]  total=25
#   ('memory', 13): sizes=[10, 10, 9]  total=29
#   ('control', 5): sizes=[5, 5, 4]  total=14
#   ('control', 9): sizes=[6, 5, 5]  total=16
#   ('control', 13): sizes=[5, 5, 5]  total=15
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=29  by load: 05=10, 09=9, 13=10
#           ctrl: total=16 by load: 05=5, 09=6, 13=5
#     TRAIN mem: total=54  by load: 05=19, 09=16, 13=19
#           ctrl: total=29 by load: 05=9, 09=10, 13=10
#   Fold 2:
#     TEST  mem: total=28  by load: 05=10, 09=8, 13=10
#           ctrl: total=15 by load: 05=5, 09=5, 13=5
#     TRAIN mem: total=55  by load: 05=19, 09=17, 13=19
#           ctrl: total=30 by load: 05=9, 09=11, 13=10
#   Fold 3:
#     TEST  mem: total=26  by load: 05=9, 09=8, 13=9
#           ctrl: total=14 by load: 05=4, 09=5, 13=5
#     TRAIN mem: total=57  by load: 05=20, 09=17, 13=20
#           ctrl: total=31 by load: 05=10, 09=11, 13=10
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 83/83 (100.0%)
#   Control test coverage 45/45 (100.0%)
# Fold 1: mem_test=29, ctrl_test=16, mem_train=54, ctrl_train=29
# saved weights for sub-056 (lag +230 ms)
# Fold 2: mem_test=28, ctrl_test=15, mem_train=55, ctrl_train=30
# saved weights for sub-056 (lag +230 ms)
# Fold 3: mem_test=26, ctrl_test=14, mem_train=57, ctrl_train=31
# saved weights for sub-056 (lag +230 ms)
# Processing subject 58...
#
# [Bucket counts]
#   ('memory', 5): 36
#   ('memory', 9): 33
#   ('memory', 13): 34
#   ('control', 5): 17
#   ('control', 9): 18
#   ('control', 13): 18
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[12, 12, 12]  total=36
#   ('memory', 9): sizes=[11, 11, 11]  total=33
#   ('memory', 13): sizes=[12, 11, 11]  total=34
#   ('control', 5): sizes=[6, 6, 5]  total=17
#   ('control', 9): sizes=[6, 6, 6]  total=18
#   ('control', 13): sizes=[6, 6, 6]  total=18
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=35  by load: 05=12, 09=11, 13=12
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=68  by load: 05=24, 09=22, 13=22
#           ctrl: total=35 by load: 05=11, 09=12, 13=12
#   Fold 2:
#     TEST  mem: total=34  by load: 05=12, 09=11, 13=11
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=69  by load: 05=24, 09=22, 13=23
#           ctrl: total=35 by load: 05=11, 09=12, 13=12
#   Fold 3:
#     TEST  mem: total=34  by load: 05=12, 09=11, 13=11
#           ctrl: total=17 by load: 05=5, 09=6, 13=6
#     TRAIN mem: total=69  by load: 05=24, 09=22, 13=23
#           ctrl: total=36 by load: 05=12, 09=12, 13=12
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 103/103 (100.0%)
#   Control test coverage 53/53 (100.0%)
# Fold 1: mem_test=35, ctrl_test=18, mem_train=68, ctrl_train=35
# saved weights for sub-058 (lag +460 ms)
# Fold 2: mem_test=34, ctrl_test=18, mem_train=69, ctrl_train=35
# saved weights for sub-058 (lag +460 ms)
# Fold 3: mem_test=34, ctrl_test=17, mem_train=69, ctrl_train=36
# saved weights for sub-058 (lag +460 ms)
# Processing subject 59...
#
# [Bucket counts]
#   ('memory', 5): 35
#   ('memory', 9): 30
#   ('memory', 13): 33
#   ('control', 5): 14
#   ('control', 9): 17
#   ('control', 13): 15
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[12, 12, 11]  total=35
#   ('memory', 9): sizes=[10, 10, 10]  total=30
#   ('memory', 13): sizes=[11, 11, 11]  total=33
#   ('control', 5): sizes=[5, 5, 4]  total=14
#   ('control', 9): sizes=[6, 6, 5]  total=17
#   ('control', 13): sizes=[5, 5, 5]  total=15
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=33  by load: 05=12, 09=10, 13=11
#           ctrl: total=16 by load: 05=5, 09=6, 13=5
#     TRAIN mem: total=65  by load: 05=23, 09=20, 13=22
#           ctrl: total=30 by load: 05=9, 09=11, 13=10
#   Fold 2:
#     TEST  mem: total=33  by load: 05=12, 09=10, 13=11
#           ctrl: total=16 by load: 05=5, 09=6, 13=5
#     TRAIN mem: total=65  by load: 05=23, 09=20, 13=22
#           ctrl: total=30 by load: 05=9, 09=11, 13=10
#   Fold 3:
#     TEST  mem: total=32  by load: 05=11, 09=10, 13=11
#           ctrl: total=14 by load: 05=4, 09=5, 13=5
#     TRAIN mem: total=66  by load: 05=24, 09=20, 13=22
#           ctrl: total=32 by load: 05=10, 09=12, 13=10
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 98/98 (100.0%)
#   Control test coverage 46/46 (100.0%)
# Fold 1: mem_test=33, ctrl_test=16, mem_train=65, ctrl_train=30
# saved weights for sub-059 (lag -70 ms)
# Fold 2: mem_test=33, ctrl_test=16, mem_train=65, ctrl_train=30
# saved weights for sub-059 (lag -70 ms)
# Fold 3: mem_test=32, ctrl_test=14, mem_train=66, ctrl_train=32
# saved weights for sub-059 (lag -70 ms)
# Processing subject 60...
#
# [Bucket counts]
#   ('memory', 5): 34
#   ('memory', 9): 35
#   ('memory', 13): 36
#   ('control', 5): 18
#   ('control', 9): 17
#   ('control', 13): 18
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[12, 11, 11]  total=34
#   ('memory', 9): sizes=[12, 12, 11]  total=35
#   ('memory', 13): sizes=[12, 12, 12]  total=36
#   ('control', 5): sizes=[6, 6, 6]  total=18
#   ('control', 9): sizes=[6, 6, 5]  total=17
#   ('control', 13): sizes=[6, 6, 6]  total=18
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=36  by load: 05=12, 09=12, 13=12
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=69  by load: 05=22, 09=23, 13=24
#           ctrl: total=35 by load: 05=12, 09=11, 13=12
#   Fold 2:
#     TEST  mem: total=35  by load: 05=11, 09=12, 13=12
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=70  by load: 05=23, 09=23, 13=24
#           ctrl: total=35 by load: 05=12, 09=11, 13=12
#   Fold 3:
#     TEST  mem: total=34  by load: 05=11, 09=11, 13=12
#           ctrl: total=17 by load: 05=6, 09=5, 13=6
#     TRAIN mem: total=71  by load: 05=23, 09=24, 13=24
#           ctrl: total=36 by load: 05=12, 09=12, 13=12
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 105/105 (100.0%)
#   Control test coverage 53/53 (100.0%)
# Fold 1: mem_test=36, ctrl_test=18, mem_train=69, ctrl_train=35
# saved weights for sub-060 (lag +1000 ms)
# Fold 2: mem_test=35, ctrl_test=18, mem_train=70, ctrl_train=35
# saved weights for sub-060 (lag +1000 ms)
# Fold 3: mem_test=34, ctrl_test=17, mem_train=71, ctrl_train=36
# saved weights for sub-060 (lag +1000 ms)
# Processing subject 62...
#
# [Bucket counts]
#   ('memory', 5): 25
#   ('memory', 9): 21
#   ('memory', 13): 18
#   ('control', 5): 12
#   ('control', 9): 10
#   ('control', 13): 12
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[9, 8, 8]  total=25
#   ('memory', 9): sizes=[7, 7, 7]  total=21
#   ('memory', 13): sizes=[6, 6, 6]  total=18
#   ('control', 5): sizes=[4, 4, 4]  total=12
#   ('control', 9): sizes=[4, 3, 3]  total=10
#   ('control', 13): sizes=[4, 4, 4]  total=12
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=22  by load: 05=9, 09=7, 13=6
#           ctrl: total=12 by load: 05=4, 09=4, 13=4
#     TRAIN mem: total=42  by load: 05=16, 09=14, 13=12
#           ctrl: total=22 by load: 05=8, 09=6, 13=8
#   Fold 2:
#     TEST  mem: total=21  by load: 05=8, 09=7, 13=6
#           ctrl: total=11 by load: 05=4, 09=3, 13=4
#     TRAIN mem: total=43  by load: 05=17, 09=14, 13=12
#           ctrl: total=23 by load: 05=8, 09=7, 13=8
#   Fold 3:
#     TEST  mem: total=21  by load: 05=8, 09=7, 13=6
#           ctrl: total=11 by load: 05=4, 09=3, 13=4
#     TRAIN mem: total=43  by load: 05=17, 09=14, 13=12
#           ctrl: total=23 by load: 05=8, 09=7, 13=8
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 64/64 (100.0%)
#   Control test coverage 34/34 (100.0%)
# Fold 1: mem_test=22, ctrl_test=12, mem_train=42, ctrl_train=22
# saved weights for sub-062 (lag -90 ms)
# Fold 2: mem_test=21, ctrl_test=11, mem_train=43, ctrl_train=23
# saved weights for sub-062 (lag -90 ms)
# Fold 3: mem_test=21, ctrl_test=11, mem_train=43, ctrl_train=23
# saved weights for sub-062 (lag -90 ms)
# Processing subject 63...
#
# [Bucket counts]
#   ('memory', 5): 33
#   ('memory', 9): 29
#   ('memory', 13): 31
#   ('control', 5): 15
#   ('control', 9): 12
#   ('control', 13): 14
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[11, 11, 11]  total=33
#   ('memory', 9): sizes=[10, 10, 9]  total=29
#   ('memory', 13): sizes=[11, 10, 10]  total=31
#   ('control', 5): sizes=[5, 5, 5]  total=15
#   ('control', 9): sizes=[4, 4, 4]  total=12
#   ('control', 13): sizes=[5, 5, 4]  total=14
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=32  by load: 05=11, 09=10, 13=11
#           ctrl: total=14 by load: 05=5, 09=4, 13=5
#     TRAIN mem: total=61  by load: 05=22, 09=19, 13=20
#           ctrl: total=27 by load: 05=10, 09=8, 13=9
#   Fold 2:
#     TEST  mem: total=31  by load: 05=11, 09=10, 13=10
#           ctrl: total=14 by load: 05=5, 09=4, 13=5
#     TRAIN mem: total=62  by load: 05=22, 09=19, 13=21
#           ctrl: total=27 by load: 05=10, 09=8, 13=9
#   Fold 3:
#     TEST  mem: total=30  by load: 05=11, 09=9, 13=10
#           ctrl: total=13 by load: 05=5, 09=4, 13=4
#     TRAIN mem: total=63  by load: 05=22, 09=20, 13=21
#           ctrl: total=28 by load: 05=10, 09=8, 13=10
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 93/93 (100.0%)
#   Control test coverage 41/41 (100.0%)
# Fold 1: mem_test=32, ctrl_test=14, mem_train=61, ctrl_train=27
# saved weights for sub-063 (lag +0 ms)
# Fold 2: mem_test=31, ctrl_test=14, mem_train=62, ctrl_train=27
# saved weights for sub-063 (lag +0 ms)
# Fold 3: mem_test=30, ctrl_test=13, mem_train=63, ctrl_train=28
# saved weights for sub-063 (lag +0 ms)
# Processing subject 64...
#
# [Bucket counts]
#   ('memory', 5): 36
#   ('memory', 9): 36
#   ('memory', 13): 33
#   ('control', 5): 18
#   ('control', 9): 18
#   ('control', 13): 18
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[12, 12, 12]  total=36
#   ('memory', 9): sizes=[12, 12, 12]  total=36
#   ('memory', 13): sizes=[11, 11, 11]  total=33
#   ('control', 5): sizes=[6, 6, 6]  total=18
#   ('control', 9): sizes=[6, 6, 6]  total=18
#   ('control', 13): sizes=[6, 6, 6]  total=18
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=35  by load: 05=12, 09=12, 13=11
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=70  by load: 05=24, 09=24, 13=22
#           ctrl: total=36 by load: 05=12, 09=12, 13=12
#   Fold 2:
#     TEST  mem: total=35  by load: 05=12, 09=12, 13=11
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=70  by load: 05=24, 09=24, 13=22
#           ctrl: total=36 by load: 05=12, 09=12, 13=12
#   Fold 3:
#     TEST  mem: total=35  by load: 05=12, 09=12, 13=11
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=70  by load: 05=24, 09=24, 13=22
#           ctrl: total=36 by load: 05=12, 09=12, 13=12
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 105/105 (100.0%)
#   Control test coverage 54/54 (100.0%)
# Fold 1: mem_test=35, ctrl_test=18, mem_train=70, ctrl_train=36
# saved weights for sub-064 (lag +530 ms)
# Fold 2: mem_test=35, ctrl_test=18, mem_train=70, ctrl_train=36
# saved weights for sub-064 (lag +530 ms)
# Fold 3: mem_test=35, ctrl_test=18, mem_train=70, ctrl_train=36
# saved weights for sub-064 (lag +530 ms)
# Processing subject 65...
#
# [Bucket counts]
#   ('memory', 5): 35
#   ('memory', 9): 33
#   ('memory', 13): 36
#   ('control', 5): 14
#   ('control', 9): 18
#   ('control', 13): 18
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[12, 12, 11]  total=35
#   ('memory', 9): sizes=[11, 11, 11]  total=33
#   ('memory', 13): sizes=[12, 12, 12]  total=36
#   ('control', 5): sizes=[5, 5, 4]  total=14
#   ('control', 9): sizes=[6, 6, 6]  total=18
#   ('control', 13): sizes=[6, 6, 6]  total=18
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=35  by load: 05=12, 09=11, 13=12
#           ctrl: total=17 by load: 05=5, 09=6, 13=6
#     TRAIN mem: total=69  by load: 05=23, 09=22, 13=24
#           ctrl: total=33 by load: 05=9, 09=12, 13=12
#   Fold 2:
#     TEST  mem: total=35  by load: 05=12, 09=11, 13=12
#           ctrl: total=17 by load: 05=5, 09=6, 13=6
#     TRAIN mem: total=69  by load: 05=23, 09=22, 13=24
#           ctrl: total=33 by load: 05=9, 09=12, 13=12
#   Fold 3:
#     TEST  mem: total=34  by load: 05=11, 09=11, 13=12
#           ctrl: total=16 by load: 05=4, 09=6, 13=6
#     TRAIN mem: total=70  by load: 05=24, 09=22, 13=24
#           ctrl: total=34 by load: 05=10, 09=12, 13=12
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 104/104 (100.0%)
#   Control test coverage 50/50 (100.0%)
# Fold 1: mem_test=35, ctrl_test=17, mem_train=69, ctrl_train=33
# saved weights for sub-065 (lag -60 ms)
# Fold 2: mem_test=35, ctrl_test=17, mem_train=69, ctrl_train=33
# saved weights for sub-065 (lag -60 ms)
# Fold 3: mem_test=34, ctrl_test=16, mem_train=70, ctrl_train=34
# saved weights for sub-065 (lag -60 ms)
# Processing subject 67...
#
# [Bucket counts]
#   ('memory', 5): 34
#   ('memory', 9): 35
#   ('memory', 13): 36
#   ('control', 5): 17
#   ('control', 9): 18
#   ('control', 13): 17
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[12, 11, 11]  total=34
#   ('memory', 9): sizes=[12, 12, 11]  total=35
#   ('memory', 13): sizes=[12, 12, 12]  total=36
#   ('control', 5): sizes=[6, 6, 5]  total=17
#   ('control', 9): sizes=[6, 6, 6]  total=18
#   ('control', 13): sizes=[6, 6, 5]  total=17
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=36  by load: 05=12, 09=12, 13=12
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
# ...
# Processing subject 86...
#
# [Bucket counts]
#   ('memory', 5): 36
#   ('memory', 9): 34
#   ('memory', 13): 34
#   ('control', 5): 16
#   ('control', 9): 17
#   ('control', 13): 18
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[12, 12, 12]  total=36
#   ('memory', 9): sizes=[12, 11, 11]  total=34
#   ('memory', 13): sizes=[12, 11, 11]  total=34
#   ('control', 5): sizes=[6, 5, 5]  total=16
#   ('control', 9): sizes=[6, 6, 5]  total=17
#   ('control', 13): sizes=[6, 6, 6]  total=18
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=36  by load: 05=12, 09=12, 13=12
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=68  by load: 05=24, 09=22, 13=22
#           ctrl: total=33 by load: 05=10, 09=11, 13=12
#   Fold 2:
#     TEST  mem: total=34  by load: 05=12, 09=11, 13=11
#           ctrl: total=17 by load: 05=5, 09=6, 13=6
#     TRAIN mem: total=70  by load: 05=24, 09=23, 13=23
#           ctrl: total=34 by load: 05=11, 09=11, 13=12
#   Fold 3:
#     TEST  mem: total=34  by load: 05=12, 09=11, 13=11
#           ctrl: total=16 by load: 05=5, 09=5, 13=6
#     TRAIN mem: total=70  by load: 05=24, 09=23, 13=23
#           ctrl: total=35 by load: 05=11, 09=12, 13=12
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 104/104 (100.0%)
#   Control test coverage 51/51 (100.0%)
# Fold 1: mem_test=36, ctrl_test=18, mem_train=68, ctrl_train=33
# saved weights for sub-086 (lag +1000 ms)
# Fold 2: mem_test=34, ctrl_test=17, mem_train=70, ctrl_train=34
# saved weights for sub-086 (lag +1000 ms)
# Fold 3: mem_test=34, ctrl_test=16, mem_train=70, ctrl_train=35
# saved weights for sub-086 (lag +1000 ms)
# Processing subject 87...
#
# [Bucket counts]
#   ('memory', 5): 29
#   ('memory', 9): 32
#   ('memory', 13): 31
#   ('control', 5): 11
#   ('control', 9): 12
#   ('control', 13): 12
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[10, 10, 9]  total=29
#   ('memory', 9): sizes=[11, 11, 10]  total=32
#   ('memory', 13): sizes=[11, 10, 10]  total=31
#   ('control', 5): sizes=[4, 4, 3]  total=11
#   ('control', 9): sizes=[4, 4, 4]  total=12
#   ('control', 13): sizes=[4, 4, 4]  total=12
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=32  by load: 05=10, 09=11, 13=11
#           ctrl: total=12 by load: 05=4, 09=4, 13=4
#     TRAIN mem: total=60  by load: 05=19, 09=21, 13=20
#           ctrl: total=23 by load: 05=7, 09=8, 13=8
#   Fold 2:
#     TEST  mem: total=31  by load: 05=10, 09=11, 13=10
#           ctrl: total=12 by load: 05=4, 09=4, 13=4
#     TRAIN mem: total=61  by load: 05=19, 09=21, 13=21
#           ctrl: total=23 by load: 05=7, 09=8, 13=8
#   Fold 3:
#     TEST  mem: total=29  by load: 05=9, 09=10, 13=10
#           ctrl: total=11 by load: 05=3, 09=4, 13=4
#     TRAIN mem: total=63  by load: 05=20, 09=22, 13=21
#           ctrl: total=24 by load: 05=8, 09=8, 13=8
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 92/92 (100.0%)
#   Control test coverage 35/35 (100.0%)
# Fold 1: mem_test=32, ctrl_test=12, mem_train=60, ctrl_train=23
# saved weights for sub-087 (lag +240 ms)
# Fold 2: mem_test=31, ctrl_test=12, mem_train=61, ctrl_train=23
# saved weights for sub-087 (lag +240 ms)
# Fold 3: mem_test=29, ctrl_test=11, mem_train=63, ctrl_train=24
# saved weights for sub-087 (lag +240 ms)
# Processing subject 88...
#
# [Bucket counts]
#   ('memory', 5): 36
#   ('memory', 9): 35
#   ('memory', 13): 36
#   ('control', 5): 18
#   ('control', 9): 17
#   ('control', 13): 18
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[12, 12, 12]  total=36
#   ('memory', 9): sizes=[12, 12, 11]  total=35
#   ('memory', 13): sizes=[12, 12, 12]  total=36
#   ('control', 5): sizes=[6, 6, 6]  total=18
#   ('control', 9): sizes=[6, 6, 5]  total=17
#   ('control', 13): sizes=[6, 6, 6]  total=18
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=36  by load: 05=12, 09=12, 13=12
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=71  by load: 05=24, 09=23, 13=24
#           ctrl: total=35 by load: 05=12, 09=11, 13=12
#   Fold 2:
#     TEST  mem: total=36  by load: 05=12, 09=12, 13=12
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=71  by load: 05=24, 09=23, 13=24
#           ctrl: total=35 by load: 05=12, 09=11, 13=12
#   Fold 3:
#     TEST  mem: total=35  by load: 05=12, 09=11, 13=12
#           ctrl: total=17 by load: 05=6, 09=5, 13=6
#     TRAIN mem: total=72  by load: 05=24, 09=24, 13=24
#           ctrl: total=36 by load: 05=12, 09=12, 13=12
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 107/107 (100.0%)
#   Control test coverage 53/53 (100.0%)
# Fold 1: mem_test=36, ctrl_test=18, mem_train=71, ctrl_train=35
# saved weights for sub-088 (lag +1000 ms)
# Fold 2: mem_test=36, ctrl_test=18, mem_train=71, ctrl_train=35
# saved weights for sub-088 (lag +1000 ms)
# Fold 3: mem_test=35, ctrl_test=17, mem_train=72, ctrl_train=36
# saved weights for sub-088 (lag +1000 ms)
# Processing subject 89...
#
# [Bucket counts]
#   ('memory', 5): 34
#   ('memory', 9): 35
#   ('memory', 13): 35
#   ('control', 5): 18
#   ('control', 9): 16
#   ('control', 13): 17
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[12, 11, 11]  total=34
#   ('memory', 9): sizes=[12, 12, 11]  total=35
#   ('memory', 13): sizes=[12, 12, 11]  total=35
#   ('control', 5): sizes=[6, 6, 6]  total=18
#   ('control', 9): sizes=[6, 5, 5]  total=16
#   ('control', 13): sizes=[6, 6, 5]  total=17
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=36  by load: 05=12, 09=12, 13=12
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=68  by load: 05=22, 09=23, 13=23
#           ctrl: total=33 by load: 05=12, 09=10, 13=11
#   Fold 2:
#     TEST  mem: total=35  by load: 05=11, 09=12, 13=12
#           ctrl: total=17 by load: 05=6, 09=5, 13=6
#     TRAIN mem: total=69  by load: 05=23, 09=23, 13=23
#           ctrl: total=34 by load: 05=12, 09=11, 13=11
#   Fold 3:
#     TEST  mem: total=33  by load: 05=11, 09=11, 13=11
#           ctrl: total=16 by load: 05=6, 09=5, 13=5
#     TRAIN mem: total=71  by load: 05=23, 09=24, 13=24
#           ctrl: total=35 by load: 05=12, 09=11, 13=12
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 104/104 (100.0%)
#   Control test coverage 51/51 (100.0%)
# Fold 1: mem_test=36, ctrl_test=18, mem_train=68, ctrl_train=33
# saved weights for sub-089 (lag -1000 ms)
# Fold 2: mem_test=35, ctrl_test=17, mem_train=69, ctrl_train=34
# saved weights for sub-089 (lag -1000 ms)
# Fold 3: mem_test=33, ctrl_test=16, mem_train=71, ctrl_train=35
# saved weights for sub-089 (lag -1000 ms)
# Processing subject 91...
#
# [Bucket counts]
#   ('memory', 5): 30
#   ('memory', 9): 26
#   ('memory', 13): 31
#   ('control', 5): 14
#   ('control', 9): 15
#   ('control', 13): 17
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[10, 10, 10]  total=30
#   ('memory', 9): sizes=[9, 9, 8]  total=26
#   ('memory', 13): sizes=[11, 10, 10]  total=31
#   ('control', 5): sizes=[5, 5, 4]  total=14
#   ('control', 9): sizes=[5, 5, 5]  total=15
#   ('control', 13): sizes=[6, 6, 5]  total=17
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=30  by load: 05=10, 09=9, 13=11
#           ctrl: total=16 by load: 05=5, 09=5, 13=6
#     TRAIN mem: total=57  by load: 05=20, 09=17, 13=20
#           ctrl: total=30 by load: 05=9, 09=10, 13=11
#   Fold 2:
#     TEST  mem: total=29  by load: 05=10, 09=9, 13=10
#           ctrl: total=16 by load: 05=5, 09=5, 13=6
#     TRAIN mem: total=58  by load: 05=20, 09=17, 13=21
#           ctrl: total=30 by load: 05=9, 09=10, 13=11
#   Fold 3:
#     TEST  mem: total=28  by load: 05=10, 09=8, 13=10
#           ctrl: total=14 by load: 05=4, 09=5, 13=5
#     TRAIN mem: total=59  by load: 05=20, 09=18, 13=21
#           ctrl: total=32 by load: 05=10, 09=10, 13=12
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 87/87 (100.0%)
#   Control test coverage 46/46 (100.0%)
# Fold 1: mem_test=30, ctrl_test=16, mem_train=57, ctrl_train=30
# saved weights for sub-091 (lag -50 ms)
# Fold 2: mem_test=29, ctrl_test=16, mem_train=58, ctrl_train=30
# saved weights for sub-091 (lag -50 ms)
# Fold 3: mem_test=28, ctrl_test=14, mem_train=59, ctrl_train=32
# saved weights for sub-091 (lag -50 ms)
# Processing subject 92...
#
# [Bucket counts]
#   ('memory', 5): 32
#   ('memory', 9): 31
#   ('memory', 13): 32
#   ('control', 5): 18
#   ('control', 9): 16
#   ('control', 13): 18
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[11, 11, 10]  total=32
#   ('memory', 9): sizes=[11, 10, 10]  total=31
#   ('memory', 13): sizes=[11, 11, 10]  total=32
#   ('control', 5): sizes=[6, 6, 6]  total=18
#   ('control', 9): sizes=[6, 5, 5]  total=16
#   ('control', 13): sizes=[6, 6, 6]  total=18
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=33  by load: 05=11, 09=11, 13=11
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=62  by load: 05=21, 09=20, 13=21
#           ctrl: total=34 by load: 05=12, 09=10, 13=12
#   Fold 2:
#     TEST  mem: total=32  by load: 05=11, 09=10, 13=11
#           ctrl: total=17 by load: 05=6, 09=5, 13=6
#     TRAIN mem: total=63  by load: 05=21, 09=21, 13=21
#           ctrl: total=35 by load: 05=12, 09=11, 13=12
#   Fold 3:
#     TEST  mem: total=30  by load: 05=10, 09=10, 13=10
#           ctrl: total=17 by load: 05=6, 09=5, 13=6
#     TRAIN mem: total=65  by load: 05=22, 09=21, 13=22
#           ctrl: total=35 by load: 05=12, 09=11, 13=12
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 95/95 (100.0%)
#   Control test coverage 52/52 (100.0%)
# Fold 1: mem_test=33, ctrl_test=18, mem_train=62, ctrl_train=34
# saved weights for sub-092 (lag +410 ms)
# Fold 2: mem_test=32, ctrl_test=17, mem_train=63, ctrl_train=35
# saved weights for sub-092 (lag +410 ms)
# Fold 3: mem_test=30, ctrl_test=17, mem_train=65, ctrl_train=35
# saved weights for sub-092 (lag +410 ms)
# Processing subject 93...
#
# [Bucket counts]
#   ('memory', 5): 36
#   ('memory', 9): 35
#   ('memory', 13): 36
#   ('control', 5): 18
#   ('control', 9): 18
#   ('control', 13): 18
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[12, 12, 12]  total=36
#   ('memory', 9): sizes=[12, 12, 11]  total=35
#   ('memory', 13): sizes=[12, 12, 12]  total=36
#   ('control', 5): sizes=[6, 6, 6]  total=18
#   ('control', 9): sizes=[6, 6, 6]  total=18
#   ('control', 13): sizes=[6, 6, 6]  total=18
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=36  by load: 05=12, 09=12, 13=12
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=71  by load: 05=24, 09=23, 13=24
#           ctrl: total=36 by load: 05=12, 09=12, 13=12
#   Fold 2:
#     TEST  mem: total=36  by load: 05=12, 09=12, 13=12
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=71  by load: 05=24, 09=23, 13=24
#           ctrl: total=36 by load: 05=12, 09=12, 13=12
#   Fold 3:
#     TEST  mem: total=35  by load: 05=12, 09=11, 13=12
#           ctrl: total=18 by load: 05=6, 09=6, 13=6
#     TRAIN mem: total=72  by load: 05=24, 09=24, 13=24
#           ctrl: total=36 by load: 05=12, 09=12, 13=12
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 107/107 (100.0%)
#   Control test coverage 54/54 (100.0%)
# Fold 1: mem_test=36, ctrl_test=18, mem_train=71, ctrl_train=36
# saved weights for sub-093 (lag +1000 ms)
# Fold 2: mem_test=36, ctrl_test=18, mem_train=71, ctrl_train=36
# saved weights for sub-093 (lag +1000 ms)
# Fold 3: mem_test=35, ctrl_test=18, mem_train=72, ctrl_train=36
# saved weights for sub-093 (lag +1000 ms)
# Processing subject 95...
#
# [Bucket counts]
#   ('memory', 5): 11
#   ('memory', 9): 14
#   ('memory', 13): 8
#   ('control', 5): 12
#   ('control', 9): 9
#   ('control', 13): 9
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[4, 4, 3]  total=11
#   ('memory', 9): sizes=[5, 5, 4]  total=14
#   ('memory', 13): sizes=[3, 3, 2]  total=8
#   ('control', 5): sizes=[4, 4, 4]  total=12
#   ('control', 9): sizes=[3, 3, 3]  total=9
#   ('control', 13): sizes=[3, 3, 3]  total=9
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=12  by load: 05=4, 09=5, 13=3
#           ctrl: total=10 by load: 05=4, 09=3, 13=3
#     TRAIN mem: total=21  by load: 05=7, 09=9, 13=5
#           ctrl: total=20 by load: 05=8, 09=6, 13=6
#   Fold 2:
#     TEST  mem: total=12  by load: 05=4, 09=5, 13=3
#           ctrl: total=10 by load: 05=4, 09=3, 13=3
#     TRAIN mem: total=21  by load: 05=7, 09=9, 13=5
#           ctrl: total=20 by load: 05=8, 09=6, 13=6
#   Fold 3:
#     TEST  mem: total=9  by load: 05=3, 09=4, 13=2
#           ctrl: total=10 by load: 05=4, 09=3, 13=3
#     TRAIN mem: total=24  by load: 05=8, 09=10, 13=6
#           ctrl: total=20 by load: 05=8, 09=6, 13=6
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 33/33 (100.0%)
#   Control test coverage 30/30 (100.0%)
# Fold 1: mem_test=12, ctrl_test=10, mem_train=21, ctrl_train=20
# saved weights for sub-095 (lag -70 ms)
# Fold 2: mem_test=12, ctrl_test=10, mem_train=21, ctrl_train=20
# saved weights for sub-095 (lag -70 ms)
# Fold 3: mem_test=9, ctrl_test=10, mem_train=24, ctrl_train=20
# saved weights for sub-095 (lag -70 ms)
# Processing subject 97...
#
# [Bucket counts]
#   ('memory', 5): 4
#   ('memory', 9): 3
#   ('memory', 13): 1
#   ('control', 5): 0
#   ('control', 9): 4
#   ('control', 13): 3
# [WARN] Not enough trials for k=3 in buckets: [('memory', 13), ('control', 5)]. Returning [].
# Subject 97 skipped – not enough trials for 3-fold stratification in all buckets.
# Processing subject 98...
#
# [Bucket counts]
#   ('memory', 5): 15
#   ('memory', 9): 13
#   ('memory', 13): 15
#   ('control', 5): 11
#   ('control', 9): 8
#   ('control', 13): 8
#
# [Chunk sizes per bucket]  (each list has k entries = fold-wise test sizes)
#   ('memory', 5): sizes=[5, 5, 5]  total=15
#   ('memory', 9): sizes=[5, 4, 4]  total=13
#   ('memory', 13): sizes=[5, 5, 5]  total=15
#   ('control', 5): sizes=[4, 4, 3]  total=11
#   ('control', 9): sizes=[3, 3, 2]  total=8
#   ('control', 13): sizes=[3, 3, 2]  total=8
#
# [Fold summaries]
#   Fold 1:
#     TEST  mem: total=15  by load: 05=5, 09=5, 13=5
#           ctrl: total=10 by load: 05=4, 09=3, 13=3
#     TRAIN mem: total=28  by load: 05=10, 09=8, 13=10
#           ctrl: total=17 by load: 05=7, 09=5, 13=5
#   Fold 2:
#     TEST  mem: total=14  by load: 05=5, 09=4, 13=5
#           ctrl: total=10 by load: 05=4, 09=3, 13=3
#     TRAIN mem: total=29  by load: 05=10, 09=9, 13=10
#           ctrl: total=17 by load: 05=7, 09=5, 13=5
#   Fold 3:
#     TEST  mem: total=14  by load: 05=5, 09=4, 13=5
#           ctrl: total=7 by load: 05=3, 09=2, 13=2
#     TRAIN mem: total=29  by load: 05=10, 09=9, 13=10
#           ctrl: total=20 by load: 05=8, 09=6, 13=6
#
# [Integrity checks]
#   Fold 1 leakage mem=0  ctrl=0
#   Fold 2 leakage mem=0  ctrl=0
#   Fold 3 leakage mem=0  ctrl=0
#   Test sets disjoint across folds? YES
#   Memory test coverage 43/43 (100.0%)
#   Control test coverage 27/27 (100.0%)
# Fold 1: mem_test=15, ctrl_test=10, mem_train=28, ctrl_train=17
# saved weights for sub-098 (lag +690 ms)
# Fold 2: mem_test=14, ctrl_test=10, mem_train=29, ctrl_train=17
# saved weights for sub-098 (lag +690 ms)
# Fold 3: mem_test=14, ctrl_test=7, mem_train=29, ctrl_train=20
# saved weights for sub-098 (lag +690 ms)
# [MEM-train only] Paired t-test: t=2.157, p_two=0.0354, p_one(mem>ctl)=0.0177, df=55

# %%
pd.DataFrame(rows_subject).to_csv("subject_level_cca_fixedlag_k3_stratCV.csv", index=False)
print("Finished – saved subject_level_cca_fixedlag_k3_stratCV.csv")
# Out:
# Finished – saved subject_level_cca_fixedlag_k3_stratCV.csv

# %%
df_subj = pd.read_csv("subject_level_cca_fixedlag_k3_stratCV.csv")

# Calculate and print mean correlations for each condition
mean_memory = df_subj[df_subj['condition'] == 'memory']['r'].mean()
mean_control = df_subj[df_subj['condition'] == 'control']['r'].mean()
print(f"Mean correlation for memory condition: {mean_memory:.4f}")
print(f"Mean correlation for control condition: {mean_control:.4f}")
print()

# Pivot so we have columns for memory and control per subject
df_wide = df_subj.pivot(index="subject", columns="condition", values="r")
print(df_wide.head(20))

# --- 95% CI for the paired mean difference (mem − ctl) ---
paired = df_wide.dropna(subset=["memory", "control"])
diff   = paired["memory"] - paired["control"]

n      = diff.size
dfree  = n - 1
mean_d = diff.mean()
se_d   = diff.std(ddof=1) / np.sqrt(n)

alpha  = 0.05
tcrit  = stats.t.ppf(1 - alpha/2, dfree)   # two-sided 95%
ci_low, ci_high = mean_d - tcrit*se_d, mean_d + tcrit*se_d

# (optional) re-run t-test on the same paired subset
t2, p2 = stats.ttest_rel(paired["memory"], paired["control"])
p_one  = p2/2 if t2 > 0 else 1 - p2/2

print(f"Paired t-test: t={t2:.3f}, p_two={p2:.4f}, "
      f"p_one(mem>ctl)={p_one:.4f}, df={dfree}, "
      f"meanΔ={mean_d:.3f}, 95% CI=[{ci_low:.3f}, {ci_high:.3f}]")
# Out:
# Mean correlation for memory condition: 0.0476
# Mean correlation for control condition: 0.0385
#
# condition   control    memory
# subject
# 33         0.021530  0.034912
# 34        -0.006766  0.008915
# 36        -0.066724 -0.058951
# 38         0.098071  0.060367
# 39         0.046827  0.041774
# 40         0.187984  0.094806
# 41         0.058574  0.009374
# 42         0.013368  0.025881
# 43         0.107334  0.068140
# 44         0.094804  0.027353
# 45         0.032783  0.058653
# 47         0.068929  0.108451
# 48        -0.010824 -0.009418
# 49         0.049490  0.104001
# 50         0.141809  0.094928
# 51         0.015450  0.092073
# 52         0.051021  0.043956
# 54         0.000040  0.008501
# 55         0.018937  0.025617
# 56        -0.021438 -0.010161
# Paired t-test: t=1.379, p_two=0.1743, p_one(mem>ctl)=0.0871, df=49, meanΔ=0.009, 95% CI=[-0.004, 0.022]
